# %%
pip install covid
# Out:
# Collecting covid
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\lib\site-packages (from covid) (4.8.0)
# Requirement already satisfied: pydantic in c:\users\admin\anaconda3\lib\site-packages (from covid) (1.4)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from covid) (2.22.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4->covid) (1.9.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->covid) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests->covid) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->covid) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->covid) (2.8)
# Installing collected packages: covid
# Successfully installed covid-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from covid import Covid

# %%
covid = Covid()
covid.get_data()
# Out:
# [{'id': '18',
#   'country': 'US',
#   'confirmed': 331151,
#   'active': 0,
#   'deaths': 9441,
#   'recovered': 16826,
#   'latitude': 40.0,
#   'longitude': -100.0,
#   'last_update': 1586115288000},
#  {'id': '160',
#   'country': 'Spain',
#   'confirmed': 130759,
#   'active': 80261,
#   'deaths': 12418,
#   'recovered': 38080,
#   'latitude': 40.463667,
#   'longitude': -3.74922,
#   'last_update': 1586115269000},
#  {'id': '11',
#   'country': 'Italy',
#   'confirmed': 128948,
#   'active': 91246,
#   'deaths': 15887,
#   'recovered': 21815,
#   'latitude': 41.8719,
#   'longitude': 12.5674,
#   'last_update': 1586115269000},
#  {'id': '8',
#   'country': 'Germany',
#   'confirmed': 100009,
#   'active': 69734,
#   'deaths': 1575,
#   'recovered': 28700,
#   'latitude': 51.1657,
#   'longitude': 10.4515,
#   'last_update': 1586115269000},
#  {'id': '7',
#   'country': 'France',
#   'confirmed': 90869,
#   'active': 67697,
#   'deaths': 7575,
#   'recovered': 15597,
#   'latitude': 46.2276,
#   'longitude': 2.2137,
#   'last_update': 1586115269000},
#  {'id': '4',
#   'country': 'China',
#   'confirmed': 82602,
#   'active': 2062,
#   'deaths': 3333,
#   'recovered': 77207,
#   'latitude': 30.5928,
#   'longitude': 114.3055,
#   'last_update': 1586078584000},
#  {'id': '90',
#   'country': 'Iran',
#   'confirmed': 58226,
#   'active': 34887,
#   'deaths': 3603,
#   'recovered': 19736,
#   'latitude': 32.427908,
#   'longitude': 53.688046,
#   'last_update': 1586115269000},
#  {'id': '17',
#   'country': 'United Kingdom',
#   'confirmed': 48407,
#   'active': 43235,
#   'deaths': 4943,
#   'recovered': 229,
#   'latitude': 55.0,
#   'longitude': -3.0,
#   'last_update': 1586115269000},
#  {'id': '172',
#   'country': 'Turkey',
#   'confirmed': 27069,
#   'active': 25453,
#   'deaths': 574,
#   'recovered': 1042,
#   'latitude': 38.9637,
#   'longitude': 35.2433,
#   'last_update': 1586115269000},
#  {'id': '16',
#   'country': 'Switzerland',
#   'confirmed': 21100,
#   'active': 13970,
#   'deaths': 715,
#   'recovered': 6415,
#   'latitude': 46.8182,
#   'longitude': 8.2275,
#   'last_update': 1586115269000},
#  {'id': '33',
#   'country': 'Belgium',
#   'confirmed': 19691,
#   'active': 14493,
#   'deaths': 1447,
#   'recovered': 3751,
#   'latitude': 50.8333,
#   'longitude': 4.469936,
#   'last_update': 1586115269000},
#  {'id': '12',
#   'country': 'Netherlands',
#   'confirmed': 17953,
#   'active': 15920,
#   'deaths': 1771,
#   'recovered': 262,
#   'latitude': 52.3167,
#   'longitude': 5.55,
#   'last_update': 1586115269000},
#  {'id': '3',
#   'country': 'Canada',
#   'confirmed': 14426,
#   'active': 0,
#   'deaths': 259,
#   'recovered': 3000,
#   'latitude': 60.001,
#   'longitude': -95.001,
#   'last_update': 1586115684000},
#  {'id': '2',
#   'country': 'Austria',
#   'confirmed': 12051,
#   'active': 8849,
#   'deaths': 204,
#   'recovered': 2998,
#   'latitude': 47.5162,
#   'longitude': 14.5501,
#   'last_update': 1586115269000},
#  {'id': '141',
#   'country': 'Portugal',
#   'confirmed': 11278,
#   'active': 10908,
#   'deaths': 295,
#   'recovered': 75,
#   'latitude': 39.3999,
#   'longitude': -8.2245,
#   'last_update': 1586115269000},
#  {'id': '40',
#   'country': 'Brazil',
#   'confirmed': 10627,
#   'active': 10040,
#   'deaths': 460,
#   'recovered': 127,
#   'latitude': -14.235,
#   'longitude': -51.9253,
#   'last_update': 1586115269000},
#  {'id': '98',
#   'country': 'Korea, South',
#   'confirmed': 10237,
#   'active': 3591,
#   'deaths': 183,
#   'recovered': 6463,
#   'latitude': 35.907757,
#   'longitude': 127.766922,
#   'last_update': 1586115269000},
#  {'id': '92',
#   'country': 'Israel',
#   'confirmed': 8430,
#   'active': 7904,
#   'deaths': 49,
#   'recovered': 477,
#   'latitude': 31.046051,
#   'longitude': 34.851612,
#   'last_update': 1586115269000},
#  {'id': '15',
#   'country': 'Sweden',
#   'confirmed': 6830,
#   'active': 6224,
#   'deaths': 401,
#   'recovered': 205,
#   'latitude': 60.1282,
#   'longitude': 18.6435,
#   'last_update': 1586115269000},
#  {'id': '1',
#   'country': 'Australia',
#   'confirmed': 5687,
#   'active': 4895,
#   'deaths': 35,
#   'recovered': 757,
#   'latitude': -25.0,
#   'longitude': 133.0,
#   'last_update': 1586115699000},
#  {'id': '13',
#   'country': 'Norway',
#   'confirmed': 5687,
#   'active': 5584,
#   'deaths': 71,
#   'recovered': 32,
#   'latitude': 60.472,
#   'longitude': 8.4689,
#   'last_update': 1586115269000},
#  {'id': '14',
#   'country': 'Russia',
#   'confirmed': 5389,
#   'active': 4989,
#   'deaths': 45,
#   'recovered': 355,
#   'latitude': 61.524,
#   'longitude': 105.3188,
#   'last_update': 1586115269000},
#  {'id': '10',
#   'country': 'Ireland',
#   'confirmed': 4994,
#   'active': 4811,
#   'deaths': 158,
#   'recovered': 25,
#   'latitude': 53.1424,
#   'longitude': -7.6921,
#   'last_update': 1586115269000},
#  {'id': '5',
#   'country': 'Denmark',
#   'confirmed': 4561,
#   'active': 2953,
#   'deaths': 179,
#   'recovered': 1429,
#   'latitude': 56.0,
#   'longitude': 10.0,
#   'last_update': 1586115269000},
#  {'id': '60',
#   'country': 'Czechia',
#   'confirmed': 4543,
#   'active': 4380,
#   'deaths': 67,
#   'recovered': 96,
#   'latitude': 49.8175,
#   'longitude': 15.473,
#   'last_update': 1586115269000},
#  {'id': '51',
#   'country': 'Chile',
#   'confirmed': 4471,
#   'active': 3819,
#   'deaths': 34,
#   'recovered': 618,
#   'latitude': -35.6751,
#   'longitude': -71.543,
#   'last_update': 1586115269000},
#  {'id': '140',
#   'country': 'Poland',
#   'confirmed': 4102,
#   'active': 3874,
#   'deaths': 94,
#   'recovered': 134,
#   'latitude': 51.9194,
#   'longitude': 19.1451,
#   'last_update': 1586115269000},
#  {'id': '143',
#   'country': 'Romania',
#   'confirmed': 3864,
#   'active': 3339,
#   'deaths': 151,
#   'recovered': 374,
#   'latitude': 45.9432,
#   'longitude': 24.9668,
#   'last_update': 1586115269000},
#  {'id': '113',
#   'country': 'Malaysia',
#   'confirmed': 3662,
#   'active': 2596,
#   'deaths': 61,
#   'recovered': 1005,
#   'latitude': 4.210484,
#   'longitude': 101.975766,
#   'last_update': 1586115269000},
#  {'id': '65',
#   'country': 'Ecuador',
#   'confirmed': 3646,
#   'active': 3366,
#   'deaths': 180,
#   'recovered': 100,
#   'latitude': -1.8312,
#   'longitude': -78.1834,
#   'last_update': 1586115269000},
#  {'id': '88',
#   'country': 'India',
#   'confirmed': 3588,
#   'active': 3260,
#   'deaths': 99,
#   'recovered': 229,
#   'latitude': 20.593684,
#   'longitude': 78.96288,
#   'last_update': 1586115269000},
#  {'id': '139',
#   'country': 'Philippines',
#   'confirmed': 3246,
#   'active': 3030,
#   'deaths': 152,
#   'recovered': 64,
#   'latitude': 12.879721,
#   'longitude': 121.774017,
#   'last_update': 1586115269000},
#  {'id': '134',
#   'country': 'Pakistan',
#   'confirmed': 3157,
#   'active': 2899,
#   'deaths': 47,
#   'recovered': 211,
#   'latitude': 30.3753,
#   'longitude': 69.3451,
#   'last_update': 1586115269000},
#  {'id': '94',
#   'country': 'Japan',
#   'confirmed': 3139,
#   'active': 2548,
#   'deaths': 77,
#   'recovered': 514,
#   'latitude': 36.204824,
#   'longitude': 138.252924,
#   'last_update': 1586115269000},
#  {'id': '109',
#   'country': 'Luxembourg',
#   'confirmed': 2804,
#   'active': 2268,
#   'deaths': 36,
#   'recovered': 500,
#   'latitude': 49.8153,
#   'longitude': 6.1296,
#   'last_update': 1586115269000},
#  {'id': '149',
#   'country': 'Saudi Arabia',
#   'confirmed': 2402,
#   'active': 1880,
#   'deaths': 34,
#   'recovered': 488,
#   'latitude': 23.885942,
#   'longitude': 45.079162,
#   'last_update': 1586115269000},
#  {'id': '138',
#   'country': 'Peru',
#   'confirmed': 2281,
#   'active': 1209,
#   'deaths': 83,
#   'recovered': 989,
#   'latitude': -9.19,
#   'longitude': -75.0152,
#   'last_update': 1586115269000},
#  {'id': '89',
#   'country': 'Indonesia',
#   'confirmed': 2273,
#   'active': 1911,
#   'deaths': 198,
#   'recovered': 164,
#   'latitude': -0.7893,
#   'longitude': 113.9213,
#   'last_update': 1586115269000},
#  {'id': '167',
#   'country': 'Thailand',
#   'confirmed': 2169,
#   'active': 1353,
#   'deaths': 23,
#   'recovered': 793,
#   'latitude': 15.870032,
#   'longitude': 100.992541,
#   'last_update': 1586115269000},
#  {'id': '6',
#   'country': 'Finland',
#   'confirmed': 1927,
#   'active': 1599,
#   'deaths': 28,
#   'recovered': 300,
#   'latitude': 61.9241,
#   'longitude': 25.7482,
#   'last_update': 1586115269000},
#  {'id': '151',
#   'country': 'Serbia',
#   'confirmed': 1908,
#   'active': 1857,
#   'deaths': 51,
#   'recovered': 0,
#   'latitude': 44.0165,
#   'longitude': 21.0059,
#   'last_update': 1586115269000},
#  {'id': '119',
#   'country': 'Mexico',
#   'confirmed': 1890,
#   'active': 1178,
#   'deaths': 79,
#   'recovered': 633,
#   'latitude': 23.6345,
#   'longitude': -102.5528,
#   'last_update': 1586115269000},
#  {'id': '135',
#   'country': 'Panama',
#   'confirmed': 1801,
#   'active': 1742,
#   'deaths': 46,
#   'recovered': 13,
#   'latitude': 8.538,
#   'longitude': -80.7821,
#   'last_update': 1586115269000},
#  {'id': '175',
#   'country': 'United Arab Emirates',
#   'confirmed': 1798,
#   'active': 1644,
#   'deaths': 10,
#   'recovered': 144,
#   'latitude': 23.424076,
#   'longitude': 53.847818,
#   'last_update': 1586115269000},
#  {'id': '64',
#   'country': 'Dominican Republic',
#   'confirmed': 1745,
#   'active': 1646,
#   'deaths': 82,
#   'recovered': 17,
#   'latitude': 18.7357,
#   'longitude': -70.1627,
#   'last_update': 1586115269000},
#  {'id': '78',
#   'country': 'Greece',
#   'confirmed': 1735,
#   'active': 1584,
#   'deaths': 73,
#   'recovered': 78,
#   'latitude': 39.0742,
#   'longitude': 21.8243,
#   'last_update': 1586115269000},
#  {'id': '142',
#   'country': 'Qatar',
#   'confirmed': 1604,
#   'active': 1477,
#   'deaths': 4,
#   'recovered': 123,
#   'latitude': 25.3548,
#   'longitude': 51.1839,
#   'last_update': 1586115269000},
#  {'id': '158',
#   'country': 'South Africa',
#   'confirmed': 1585,
#   'active': 1481,
#   'deaths': 9,
#   'recovered': 95,
#   'latitude': -30.5595,
#   'longitude': 22.9375,
#   'last_update': 1586115269000},
#  {'id': '9',
#   'country': 'Iceland',
#   'confirmed': 1486,
#   'active': 1054,
#   'deaths': 4,
#   'recovered': 428,
#   'latitude': 64.9631,
#   'longitude': -19.0208,
#   'last_update': 1586115269000},
#  {'id': '52',
#   'country': 'Colombia',
#   'confirmed': 1485,
#   'active': 1362,
#   'deaths': 35,
#   'recovered': 88,
#   'latitude': 4.5709,
#   'longitude': -74.2973,
#   'last_update': 1586115269000},
#  {'id': '25',
#   'country': 'Argentina',
#   'confirmed': 1451,
#   'active': 1127,
#   'deaths': 44,
#   'recovered': 280,
#   'latitude': -38.4161,
#   'longitude': -63.6167,
#   'last_update': 1586115269000},
#  {'id': '21',
#   'country': 'Algeria',
#   'confirmed': 1320,
#   'active': 1078,
#   'deaths': 152,
#   'recovered': 90,
#   'latitude': 28.0339,
#   'longitude': 1.6596,
#   'last_update': 1586115269000},
#  {'id': '154',
#   'country': 'Singapore',
#   'confirmed': 1309,
#   'active': 983,
#   'deaths': 6,
#   'recovered': 320,
#   'latitude': 1.2833,
#   'longitude': 103.8333,
#   'last_update': 1586115269000},
#  {'id': '174',
#   'country': 'Ukraine',
#   'confirmed': 1308,
#   'active': 1243,
#   'deaths': 37,
#   'recovered': 28,
#   'latitude': 48.3794,
#   'longitude': 31.1656,
#   'last_update': 1586115269000},
#  {'id': '57',
#   'country': 'Croatia',
#   'confirmed': 1182,
#   'active': 1042,
#   'deaths': 15,
#   'recovered': 125,
#   'latitude': 45.1,
#   'longitude': 15.2,
#   'last_update': 1586115269000},
#  {'id': '66',
#   'country': 'Egypt',
#   'confirmed': 1173,
#   'active': 848,
#   'deaths': 78,
#   'recovered': 247,
#   'latitude': 26.820553,
#   'longitude': 30.802498,
#   'last_update': 1586115269000},
#  {'id': '70',
#   'country': 'Estonia',
#   'confirmed': 1097,
#   'active': 1020,
#   'deaths': 15,
#   'recovered': 62,
#   'latitude': 58.5953,
#   'longitude': 25.0136,
#   'last_update': 1586115269000},
#  {'id': '128',
#   'country': 'New Zealand',
#   'confirmed': 1039,
#   'active': 882,
#   'deaths': 1,
#   'recovered': 156,
#   'latitude': -40.9006,
#   'longitude': 174.886,
#   'last_update': 1586115269000},
#  {'id': '156',
#   'country': 'Slovenia',
#   'confirmed': 997,
#   'active': 890,
#   'deaths': 28,
#   'recovered': 79,
#   'latitude': 46.1512,
#   'longitude': 14.9955,
#   'last_update': 1586115269000},
#  {'id': '124',
#   'country': 'Morocco',
#   'confirmed': 990,
#   'active': 850,
#   'deaths': 69,
#   'recovered': 71,
#   'latitude': 31.7917,
#   'longitude': -7.0926,
#   'last_update': 1586115269000},
#  {'id': '91',
#   'country': 'Iraq',
#   'confirmed': 961,
#   'active': 621,
#   'deaths': 61,
#   'recovered': 279,
#   'latitude': 33.223191,
#   'longitude': 43.679291,
#   'last_update': 1586115269000},
#  {'id': '120',
#   'country': 'Moldova',
#   'confirmed': 864,
#   'active': 819,
#   'deaths': 15,
#   'recovered': 30,
#   'latitude': 47.4116,
#   'longitude': 28.3699,
#   'last_update': 1586115269000},
#  {'id': '26',
#   'country': 'Armenia',
#   'confirmed': 822,
#   'active': 758,
#   'deaths': 7,
#   'recovered': 57,
#   'latitude': 40.0691,
#   'longitude': 45.0382,
#   'last_update': 1586115269000},
#  {'id': '108',
#   'country': 'Lithuania',
#   'confirmed': 811,
#   'active': 791,
#   'deaths': 13,
#   'recovered': 7,
#   'latitude': 55.1694,
#   'longitude': 23.8813,
#   'last_update': 1586115269000},
#  {'id': '87',
#   'country': 'Hungary',
#   'confirmed': 733,
#   'active': 633,
#   'deaths': 34,
#   'recovered': 66,
#   'latitude': 47.1625,
#   'longitude': 19.5033,
#   'last_update': 1586115269000},
#  {'id': '61',
#   'country': 'Diamond Princess',
#   'confirmed': 712,
#   'active': 82,
#   'deaths': 11,
#   'recovered': 619,
#   'latitude': None,
#   'longitude': None,
#   'last_update': 1586115269000},
#  {'id': '29',
#   'country': 'Bahrain',
#   'confirmed': 698,
#   'active': 267,
#   'deaths': 4,
#   'recovered': 427,
#   'latitude': 26.0275,
#   'longitude': 50.55,
#   'last_update': 1586115269000},
#  {'id': '38',
#   'country': 'Bosnia and Herzegovina',
#   'confirmed': 654,
#   'active': 601,
#   'deaths': 23,
#   'recovered': 30,
#   'latitude': 43.9159,
#   'longitude': 17.6791,
#   'last_update': 1586115269000},
#  {'id': '27',
#   'country': 'Azerbaijan',
#   'confirmed': 584,
#   'active': 545,
#   'deaths': 7,
#   'recovered': 32,
#   'latitude': 40.1431,
#   'longitude': 47.5769,
#   'last_update': 1586115269000},
#  {'id': '96',
#   'country': 'Kazakhstan',
#   'confirmed': 584,
#   'active': 536,
#   'deaths': 6,
#   'recovered': 42,
#   'latitude': 48.0196,
#   'longitude': 66.9237,
#   'last_update': 1586115269000},
#  {'id': '171',
#   'country': 'Tunisia',
#   'confirmed': 574,
#   'active': 547,
#   'deaths': 22,
#   'recovered': 5,
#   'latitude': 33.886917,
#   'longitude': 9.537499,
#   'last_update': 1586115269000},
#  {'id': '32',
#   'country': 'Belarus',
#   'confirmed': 562,
#   'active': 502,
#   'deaths': 8,
#   'recovered': 52,
#   'latitude': 53.7098,
#   'longitude': 27.9534,
#   'last_update': 1586115269000},
#  {'id': '100',
#   'country': 'Kuwait',
#   'confirmed': 556,
#   'active': 456,
#   'deaths': 1,
#   'recovered': 99,
#   'latitude': 29.31166,
#   'longitude': 47.481766,
#   'last_update': 1586115269000},
#  {'id': '48',
#   'country': 'Cameroon',
#   'confirmed': 555,
#   'active': 529,
#   'deaths': 9,
#   'recovered': 17,
#   'latitude': 3.848,
#   'longitude': 11.5021,
#   'last_update': 1586115269000},
#  {'id': '132',
#   'country': 'North Macedonia',
#   'confirmed': 555,
#   'active': 514,
#   'deaths': 18,
#   'recovered': 23,
#   'latitude': 41.6086,
#   'longitude': 21.7453,
#   'last_update': 1586115269000},
#  {'id': '103',
#   'country': 'Latvia',
#   'confirmed': 533,
#   'active': 531,
#   'deaths': 1,
#   'recovered': 1,
#   'latitude': 56.8796,
#   'longitude': 24.6032,
#   'last_update': 1586115269000},
#  {'id': '42',
#   'country': 'Bulgaria',
#   'confirmed': 531,
#   'active': 474,
#   'deaths': 20,
#   'recovered': 37,
#   'latitude': 42.7339,
#   'longitude': 25.4858,
#   'last_update': 1586115269000},
#  {'id': '104',
#   'country': 'Lebanon',
#   'confirmed': 527,
#   'active': 455,
#   'deaths': 18,
#   'recovered': 54,
#   'latitude': 33.8547,
#   'longitude': 35.8623,
#   'last_update': 1586115269000},
#  {'id': '22',
#   'country': 'Andorra',
#   'confirmed': 501,
#   'active': 457,
#   'deaths': 18,
#   'recovered': 26,
#   'latitude': 42.5063,
#   'longitude': 1.5218,
#   'last_update': 1586115269000},
#  {'id': '155',
#   'country': 'Slovakia',
#   'confirmed': 485,
#   'active': 474,
#   'deaths': 1,
#   'recovered': 10,
#   'latitude': 48.669,
#   'longitude': 19.699,
#   'last_update': 1586115269000},
#  {'id': '55',
#   'country': 'Costa Rica',
#   'confirmed': 454,
#   'active': 436,
#   'deaths': 2,
#   'recovered': 16,
#   'latitude': 9.7489,
#   'longitude': -83.7534,
#   'last_update': 1586115269000},
#  {'id': '59',
#   'country': 'Cyprus',
#   'confirmed': 446,
#   'active': 400,
#   'deaths': 9,
#   'recovered': 37,
#   'latitude': 35.1264,
#   'longitude': 33.4299,
#   'last_update': 1586115269000},
#  {'id': '176',
#   'country': 'Uruguay',
#   'confirmed': 400,
#   'active': 302,
#   'deaths': 5,
#   'recovered': 93,
#   'latitude': -32.5228,
#   'longitude': -55.7658,
#   'last_update': 1586115269000},
#  {'id': '165',
#   'country': 'Taiwan*',
#   'confirmed': 363,
#   'active': 308,
#   'deaths': 5,
#   'recovered': 50,
#   'latitude': 23.7,
#   'longitude': 121.0,
#   'last_update': 1586084047000},
#  {'id': '20',
#   'country': 'Albania',
#   'confirmed': 361,
#   'active': 237,
#   'deaths': 20,
#   'recovered': 104,
#   'latitude': 41.1533,
#   'longitude': 20.1683,
#   'last_update': 1586115269000},
#  {'id': '19',
#   'country': 'Afghanistan',
#   'confirmed': 349,
#   'active': 327,
#   'deaths': 7,
#   'recovered': 15,
#   'latitude': 33.93911,
#   'longitude': 67.709953,
#   'last_update': 1586115269000},
#  {'id': '43',
#   'country': 'Burkina Faso',
#   'confirmed': 345,
#   'active': 238,
#   'deaths': 17,
#   'recovered': 90,
#   'latitude': 12.2383,
#   'longitude': -1.5616,
#   'last_update': 1586115269000},
#  {'id': '95',
#   'country': 'Jordan',
#   'confirmed': 345,
#   'active': 230,
#   'deaths': 5,
#   'recovered': 110,
#   'latitude': 31.24,
#   'longitude': 36.51,
#   'last_update': 1586115269000},
#  {'id': '177',
#   'country': 'Uzbekistan',
#   'confirmed': 342,
#   'active': 310,
#   'deaths': 2,
#   'recovered': 30,
#   'latitude': 41.377491,
#   'longitude': 64.585262,
#   'last_update': 1586115269000},
#  {'id': '58',
#   'country': 'Cuba',
#   'confirmed': 320,
#   'active': 297,
#   'deaths': 8,
#   'recovered': 15,
#   'latitude': 21.521757,
#   'longitude': -77.781167,
#   'last_update': 1586115269000},
#  {'id': '133',
#   'country': 'Oman',
#   'confirmed': 298,
#   'active': 235,
#   'deaths': 2,
#   'recovered': 61,
#   'latitude': 21.512583,
#   'longitude': 55.923255,
#   'last_update': 1586115269000},
#  {'id': '86',
#   'country': 'Honduras',
#   'confirmed': 268,
#   'active': 240,
#   'deaths': 22,
#   'recovered': 6,
#   'latitude': 15.2,
#   'longitude': -86.2419,
#   'last_update': 1586115269000},
#  {'id': '148',
#   'country': 'San Marino',
#   'confirmed': 266,
#   'active': 199,
#   'deaths': 32,
#   'recovered': 35,
#   'latitude': 43.9424,
#   'longitude': 12.4578,
#   'last_update': 1586115269000},
#  {'id': '56',
#   'country': "Cote d'Ivoire",
#   'confirmed': 245,
#   'active': 219,
#   'deaths': 1,
#   'recovered': 25,
#   'latitude': 7.54,
#   'longitude': -5.5471,
#   'last_update': 1586115269000},
#  {'id': '179',
#   'country': 'Vietnam',
#   'confirmed': 241,
#   'active': 151,
#   'deaths': 0,
#   'recovered': 90,
#   'latitude': 14.058324,
#   'longitude': 108.277199,
#   'last_update': 1586115269000},
#  {'id': '180',
#   'country': 'West Bank and Gaza',
#   'confirmed': 234,
#   'active': 210,
#   'deaths': 1,
#   'recovered': 23,
#   'latitude': 31.9522,
#   'longitude': 35.2332,
#   'last_update': 1586115269000},
#  {'id': '116',
#   'country': 'Malta',
#   'confirmed': 227,
#   'active': 222,
#   'deaths': 0,
#   'recovered': 5,
#   'latitude': 35.9375,
#   'longitude': 14.3754,
#   'last_update': 1586115269000},
#  {'id': '118',
#   'country': 'Mauritius',
#   'confirmed': 227,
#   'active': 213,
#   'deaths': 7,
#   'recovered': 7,
#   'latitude': -20.348404,
#   'longitude': 57.552152,
#   'last_update': 1586115269000},
#  {'id': '131',
#   'country': 'Nigeria',
#   'confirmed': 224,
#   'active': 192,
#   'deaths': 5,
#   'recovered': 27,
#   'latitude': 9.082,
#   'longitude': 8.6753,
#   'last_update': 1586115269000},
#  {'id': '150',
#   'country': 'Senegal',
#   'confirmed': 222,
#   'active': 138,
#   'deaths': 2,
#   'recovered': 82,
#   'latitude': 14.4974,
#   'longitude': -14.4524,
#   'last_update': 1586115269000},
#  {'id': '77',
#   'country': 'Ghana',
#   'confirmed': 214,
#   'active': 178,
#   'deaths': 5,
#   'recovered': 31,
#   'latitude': 7.9465,
#   'longitude': -1.0232,
#   'last_update': 1586115269000},
#  {'id': '123',
#   'country': 'Montenegro',
#   'confirmed': 214,
#   'active': 211,
#   'deaths': 2,
#   'recovered': 1,
#   'latitude': 42.708678,
#   'longitude': 19.37439,
#   'last_update': 1586115269000},
#  {'id': '161',
#   'country': 'Sri Lanka',
#   'confirmed': 176,
#   'active': 138,
#   'deaths': 5,
#   'recovered': 33,
#   'latitude': 7.873054,
#   'longitude': 80.771797,
#   'last_update': 1586115269000},
#  {'id': '76',
#   'country': 'Georgia',
#   'confirmed': 174,
#   'active': 136,
#   'deaths': 2,
#   'recovered': 36,
#   'latitude': 42.3154,
#   'longitude': 43.3569,
#   'last_update': 1586115269000},
#  {'id': '178',
#   'country': 'Venezuela',
#   'confirmed': 159,
#   'active': 100,
#   'deaths': 7,
#   'recovered': 52,
#   'latitude': 6.4238,
#   'longitude': -66.5897,
#   'last_update': 1586115269000},
#  {'id': '37',
#   'country': 'Bolivia',
#   'confirmed': 157,
#   'active': 145,
#   'deaths': 10,
#   'recovered': 2,
#   'latitude': -16.2902,
#   'longitude': -63.5887,
#   'last_update': 1586115269000},
#  {'id': '54',
#   'country': 'Congo (Kinshasa)',
#   'confirmed': 154,
#   'active': 133,
#   'deaths': 18,
#   'recovered': 3,
#   'latitude': -4.322447,
#   'longitude': 15.307045,
#   'last_update': 1586115269000},
#  {'id': '101',
#   'country': 'Kyrgyzstan',
#   'confirmed': 147,
#   'active': 137,
#   'deaths': 1,
#   'recovered': 9,
#   'latitude': 41.20438,
#   'longitude': 74.766098,
#   'last_update': 1586115269000},
#  {'id': '99',
#   'country': 'Kosovo',
#   'confirmed': 145,
#   'active': 121,
#   'deaths': 1,
#   'recovered': 23,
#   'latitude': 42.602636,
#   'longitude': 20.902977,
#   'last_update': 1586115269000},
#  {'id': '130',
#   'country': 'Niger',
#   'confirmed': 144,
#   'active': 136,
#   'deaths': 8,
#   'recovered': 0,
#   'latitude': 17.607789,
#   'longitude': 8.081666,
#   'last_update': 1586115269000},
#  {'id': '97',
#   'country': 'Kenya',
#   'confirmed': 142,
#   'active': 134,
#   'deaths': 4,
#   'recovered': 4,
#   'latitude': -0.0236,
#   'longitude': 37.9062,
#   'last_update': 1586115269000},
#  {'id': '41',
#   'country': 'Brunei',
#   'confirmed': 135,
#   'active': 61,
#   'deaths': 1,
#   'recovered': 73,
#   'latitude': 4.5353,
#   'longitude': 114.7277,
#   'last_update': 1586115269000},
#  {'id': '81',
#   'country': 'Guinea',
#   'confirmed': 121,
#   'active': 116,
#   'deaths': 0,
#   'recovered': 5,
#   'latitude': 9.9456,
#   'longitude': -9.6966,
#   'last_update': 1586115269000},
#  {'id': '47',
#   'country': 'Cambodia',
#   'confirmed': 114,
#   'active': 64,
#   'deaths': 0,
#   'recovered': 50,
#   'latitude': 11.55,
#   'longitude': 104.9167,
#   'last_update': 1586115269000},
#  {'id': '137',
#   'country': 'Paraguay',
#   'confirmed': 104,
#   'active': 89,
#   'deaths': 3,
#   'recovered': 12,
#   'latitude': -23.4425,
#   'longitude': -58.4438,
#   'last_update': 1586115269000},
#  {'id': '144',
#   'country': 'Rwanda',
#   'confirmed': 104,
#   'active': 100,
#   'deaths': 0,
#   'recovered': 4,
#   'latitude': -1.9403,
#   'longitude': 29.8739,
#   'last_update': 1586115269000},
#  {'id': '170',
#   'country': 'Trinidad and Tobago',
#   'confirmed': 104,
#   'active': 96,
#   'deaths': 7,
#   'recovered': 1,
#   'latitude': 10.6918,
#   'longitude': -61.2225,
#   'last_update': 1586115269000},
#  {'id': '30',
#   'country': 'Bangladesh',
#   'confirmed': 88,
#   'active': 46,
#   'deaths': 9,
#   'recovered': 33,
#   'latitude': 23.685,
#   'longitude': 90.3563,
#   'last_update': 1586115269000},
#  {'id': '107',
#   'country': 'Liechtenstein',
#   'confirmed': 77,
#   'active': 76,
#   'deaths': 1,
#   'recovered': 0,
#   'latitude': 47.14,
#   'longitude': 9.55,
#   'last_update': 1586115269000},
#  {'id': '121',
#   'country': 'Monaco',
#   'confirmed': 73,
#   'active': 69,
#   'deaths': 1,
#   'recovered': 3,
#   'latitude': 43.7333,
#   'longitude': 7.4167,
#   'last_update': 1586115269000},
#  {'id': '111',
#   'country': 'Madagascar',
#   'confirmed': 72,
#   'active': 70,
#   'deaths': 0,
#   'recovered': 2,
#   'latitude': -18.766947,
#   'longitude': 46.869107,
#   'last_update': 1586115269000},
#  {'id': '67',
#   'country': 'El Salvador',
#   'confirmed': 62,
#   'active': 57,
#   'deaths': 3,
#   'recovered': 2,
#   'latitude': 13.7942,
#   'longitude': -88.8965,
#   'last_update': 1586115269000},
#  {'id': '80',
#   'country': 'Guatemala',
#   'confirmed': 61,
#   'active': 44,
#   'deaths': 2,
#   'recovered': 15,
#   'latitude': 15.7835,
#   'longitude': -90.2308,
#   'last_update': 1586115269000},
#  {'id': '62',
#   'country': 'Djibouti',
#   'confirmed': 59,
#   'active': 50,
#   'deaths': 0,
#   'recovered': 9,
#   'latitude': 11.8251,
#   'longitude': 42.5903,
#   'last_update': 1586115269000},
#  {'id': '31',
#   'country': 'Barbados',
#   'confirmed': 56,
#   'active': 49,
#   'deaths': 1,
#   'recovered': 6,
#   'latitude': 13.1939,
#   'longitude': -59.5432,
#   'last_update': 1586115269000},
#  {'id': '93',
#   'country': 'Jamaica',
#   'confirmed': 55,
#   'active': 45,
#   'deaths': 3,
#   'recovered': 7,
#   'latitude': 18.1096,
#   'longitude': -77.2975,
#   'last_update': 1586115269000},
#  {'id': '173',
#   'country': 'Uganda',
#   'confirmed': 48,
#   'active': 48,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 1.373333,
#   'longitude': 32.290275,
#   'last_update': 1586115269000},
#  {'id': '53',
#   'country': 'Congo (Brazzaville)',
#   'confirmed': 45,
#   'active': 38,
#   'deaths': 5,
#   'recovered': 2,
#   'latitude': -4.2634,
#   'longitude': 15.2832,
#   'last_update': 1586115269000},
#  {'id': '115',
#   'country': 'Mali',
#   'confirmed': 45,
#   'active': 39,
#   'deaths': 5,
#   'recovered': 1,
#   'latitude': 17.570692,
#   'longitude': -3.996166,
#   'last_update': 1586115269000},
#  {'id': '169',
#   'country': 'Togo',
#   'confirmed': 44,
#   'active': 21,
#   'deaths': 3,
#   'recovered': 20,
#   'latitude': 8.6195,
#   'longitude': 0.8248,
#   'last_update': 1586115269000},
#  {'id': '72',
#   'country': 'Ethiopia',
#   'confirmed': 43,
#   'active': 37,
#   'deaths': 2,
#   'recovered': 4,
#   'latitude': 9.145,
#   'longitude': 40.4897,
#   'last_update': 1586115269000},
#  {'id': '182',
#   'country': 'Zambia',
#   'confirmed': 39,
#   'active': 35,
#   'deaths': 1,
#   'recovered': 3,
#   'latitude': -13.133897,
#   'longitude': 27.849332,
#   'last_update': 1586115269000},
#  {'id': '69',
#   'country': 'Eritrea',
#   'confirmed': 29,
#   'active': 29,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 15.1794,
#   'longitude': 39.7823,
#   'last_update': 1586115269000},
#  {'id': '28',
#   'country': 'Bahamas',
#   'confirmed': 28,
#   'active': 24,
#   'deaths': 4,
#   'recovered': 0,
#   'latitude': 25.025885,
#   'longitude': -78.035889,
#   'last_update': 1586115269000},
#  {'id': '83',
#   'country': 'Guyana',
#   'confirmed': 24,
#   'active': 20,
#   'deaths': 4,
#   'recovered': 0,
#   'latitude': 4.860416,
#   'longitude': -58.93018,
#   'last_update': 1586115269000},
#  {'id': '35',
#   'country': 'Benin',
#   'confirmed': 22,
#   'active': 17,
#   'deaths': 0,
#   'recovered': 5,
#   'latitude': 9.3077,
#   'longitude': 2.3158,
#   'last_update': 1586115269000},
#  {'id': '44',
#   'country': 'Burma',
#   'confirmed': 21,
#   'active': 20,
#   'deaths': 1,
#   'recovered': 0,
#   'latitude': 21.9162,
#   'longitude': 95.956,
#   'last_update': 1586115269000},
#  {'id': '74',
#   'country': 'Gabon',
#   'confirmed': 21,
#   'active': 19,
#   'deaths': 1,
#   'recovered': 1,
#   'latitude': -0.8037,
#   'longitude': 11.6094,
#   'last_update': 1586115269000},
#  {'id': '84',
#   'country': 'Haiti',
#   'confirmed': 21,
#   'active': 19,
#   'deaths': 1,
#   'recovered': 1,
#   'latitude': 18.9712,
#   'longitude': -72.2852,
#   'last_update': 1586115269000},
#  {'id': '166',
#   'country': 'Tanzania',
#   'confirmed': 20,
#   'active': 16,
#   'deaths': 1,
#   'recovered': 3,
#   'latitude': -6.369028,
#   'longitude': 34.888822,
#   'last_update': 1586115269000},
#  {'id': '114',
#   'country': 'Maldives',
#   'confirmed': 19,
#   'active': 6,
#   'deaths': 0,
#   'recovered': 13,
#   'latitude': 3.2028,
#   'longitude': 73.2207,
#   'last_update': 1586115269000},
#  {'id': '164',
#   'country': 'Syria',
#   'confirmed': 19,
#   'active': 15,
#   'deaths': 2,
#   'recovered': 2,
#   'latitude': 34.802075,
#   'longitude': 38.996815,
#   'last_update': 1586115269000},
#  {'id': '82',
#   'country': 'Guinea-Bissau',
#   'confirmed': 18,
#   'active': 18,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 11.8037,
#   'longitude': -15.1804,
#   'last_update': 1586115269000},
#  {'id': '106',
#   'country': 'Libya',
#   'confirmed': 18,
#   'active': 17,
#   'deaths': 1,
#   'recovered': 0,
#   'latitude': 26.3351,
#   'longitude': 17.228331,
#   'last_update': 1586115269000},
#  {'id': '68',
#   'country': 'Equatorial Guinea',
#   'confirmed': 16,
#   'active': 15,
#   'deaths': 0,
#   'recovered': 1,
#   'latitude': 1.6508,
#   'longitude': 10.2679,
#   'last_update': 1586115269000},
#  {'id': '126',
#   'country': 'Namibia',
#   'confirmed': 16,
#   'active': 13,
#   'deaths': 0,
#   'recovered': 3,
#   'latitude': -22.9576,
#   'longitude': 18.4904,
#   'last_update': 1586115269000},
#  {'id': '24',
#   'country': 'Antigua and Barbuda',
#   'confirmed': 15,
#   'active': 15,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 17.0608,
#   'longitude': -61.7964,
#   'last_update': 1586115269000},
#  {'id': '63',
#   'country': 'Dominica',
#   'confirmed': 14,
#   'active': 14,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 15.415,
#   'longitude': -61.371,
#   'last_update': 1586115269000},
#  {'id': '122',
#   'country': 'Mongolia',
#   'confirmed': 14,
#   'active': 12,
#   'deaths': 0,
#   'recovered': 2,
#   'latitude': 46.8625,
#   'longitude': 103.8467,
#   'last_update': 1586115269000},
#  {'id': '146',
#   'country': 'Saint Lucia',
#   'confirmed': 14,
#   'active': 13,
#   'deaths': 0,
#   'recovered': 1,
#   'latitude': 13.9094,
#   'longitude': -60.9789,
#   'last_update': 1586115269000},
#  {'id': '105',
#   'country': 'Liberia',
#   'confirmed': 13,
#   'active': 7,
#   'deaths': 3,
#   'recovered': 3,
#   'latitude': 6.428055,
#   'longitude': -9.429499,
#   'last_update': 1586115269000},
#  {'id': '73',
#   'country': 'Fiji',
#   'confirmed': 12,
#   'active': 12,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': -17.7134,
#   'longitude': 178.065,
#   'last_update': 1586115269000},
#  {'id': '79',
#   'country': 'Grenada',
#   'confirmed': 12,
#   'active': 12,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 12.1165,
#   'longitude': -61.679,
#   'last_update': 1586115269000},
#  {'id': '162',
#   'country': 'Sudan',
#   'confirmed': 12,
#   'active': 8,
#   'deaths': 2,
#   'recovered': 2,
#   'latitude': 12.8628,
#   'longitude': 30.2176,
#   'last_update': 1586115269000},
#  {'id': '102',
#   'country': 'Laos',
#   'confirmed': 11,
#   'active': 11,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 19.85627,
#   'longitude': 102.495496,
#   'last_update': 1586115269000},
#  {'id': '23',
#   'country': 'Angola',
#   'confirmed': 10,
#   'active': 6,
#   'deaths': 2,
#   'recovered': 2,
#   'latitude': -11.2027,
#   'longitude': 17.8739,
#   'last_update': 1586115269000},
#  {'id': '125',
#   'country': 'Mozambique',
#   'confirmed': 10,
#   'active': 9,
#   'deaths': 0,
#   'recovered': 1,
#   'latitude': -18.665695,
#   'longitude': 35.529562,
#   'last_update': 1586115269000},
#  {'id': '145',
#   'country': 'Saint Kitts and Nevis',
#   'confirmed': 10,
#   'active': 10,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 17.357822,
#   'longitude': -62.782998,
#   'last_update': 1586115269000},
#  {'id': '152',
#   'country': 'Seychelles',
#   'confirmed': 10,
#   'active': 10,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': -4.6796,
#   'longitude': 55.492,
#   'last_update': 1586115269000},
#  {'id': '163',
#   'country': 'Suriname',
#   'confirmed': 10,
#   'active': 9,
#   'deaths': 1,
#   'recovered': 0,
#   'latitude': 3.9193,
#   'longitude': -56.0278,
#   'last_update': 1586115269000},
#  {'id': '50',
#   'country': 'Chad',
#   'confirmed': 9,
#   'active': 9,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 15.4542,
#   'longitude': 18.7322,
#   'last_update': 1586115269000},
#  {'id': '71',
#   'country': 'Eswatini',
#   'confirmed': 9,
#   'active': 9,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': -26.5225,
#   'longitude': 31.4659,
#   'last_update': 1586115269000},
#  {'id': '110',
#   'country': 'MS Zaandam',
#   'confirmed': 9,
#   'active': 7,
#   'deaths': 2,
#   'recovered': 0,
#   'latitude': None,
#   'longitude': None,
#   'last_update': 1586115269000},
#  {'id': '127',
#   'country': 'Nepal',
#   'confirmed': 9,
#   'active': 8,
#   'deaths': 0,
#   'recovered': 1,
#   'latitude': 28.1667,
#   'longitude': 84.25,
#   'last_update': 1586115269000},
#  {'id': '183',
#   'country': 'Zimbabwe',
#   'confirmed': 9,
#   'active': 8,
#   'deaths': 1,
#   'recovered': 0,
#   'latitude': -19.015438,
#   'longitude': 29.154857,
#   'last_update': 1586115269000},
#  {'id': '49',
#   'country': 'Central African Republic',
#   'confirmed': 8,
#   'active': 8,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 6.6111,
#   'longitude': 20.9394,
#   'last_update': 1586115269000},
#  {'id': '46',
#   'country': 'Cabo Verde',
#   'confirmed': 7,
#   'active': 6,
#   'deaths': 1,
#   'recovered': 0,
#   'latitude': 16.5388,
#   'longitude': -23.0418,
#   'last_update': 1586115269000},
#  {'id': '85',
#   'country': 'Holy See',
#   'confirmed': 7,
#   'active': 7,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 41.9029,
#   'longitude': 12.4534,
#   'last_update': 1586115269000},
#  {'id': '147',
#   'country': 'Saint Vincent and the Grenadines',
#   'confirmed': 7,
#   'active': 6,
#   'deaths': 0,
#   'recovered': 1,
#   'latitude': 12.9843,
#   'longitude': -61.2872,
#   'last_update': 1586115269000},
#  {'id': '157',
#   'country': 'Somalia',
#   'confirmed': 7,
#   'active': 6,
#   'deaths': 0,
#   'recovered': 1,
#   'latitude': 5.152149,
#   'longitude': 46.199616,
#   'last_update': 1586115269000},
#  {'id': '39',
#   'country': 'Botswana',
#   'confirmed': 6,
#   'active': 5,
#   'deaths': 1,
#   'recovered': 0,
#   'latitude': -22.3285,
#   'longitude': 24.6849,
#   'last_update': 1586115269000},
#  {'id': '117',
#   'country': 'Mauritania',
#   'confirmed': 6,
#   'active': 3,
#   'deaths': 1,
#   'recovered': 2,
#   'latitude': 21.0079,
#   'longitude': -10.9408,
#   'last_update': 1586115269000},
#  {'id': '129',
#   'country': 'Nicaragua',
#   'confirmed': 6,
#   'active': 5,
#   'deaths': 1,
#   'recovered': 0,
#   'latitude': 12.865416,
#   'longitude': -85.207229,
#   'last_update': 1586115269000},
#  {'id': '153',
#   'country': 'Sierra Leone',
#   'confirmed': 6,
#   'active': 6,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 8.460555,
#   'longitude': -11.779889,
#   'last_update': 1586115269000},
#  {'id': '34',
#   'country': 'Belize',
#   'confirmed': 5,
#   'active': 5,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 17.1899,
#   'longitude': -88.4976,
#   'last_update': 1586115269000},
#  {'id': '36',
#   'country': 'Bhutan',
#   'confirmed': 5,
#   'active': 3,
#   'deaths': 0,
#   'recovered': 2,
#   'latitude': 27.5142,
#   'longitude': 90.4336,
#   'last_update': 1586115269000},
#  {'id': '75',
#   'country': 'Gambia',
#   'confirmed': 4,
#   'active': 1,
#   'deaths': 1,
#   'recovered': 2,
#   'latitude': 13.4432,
#   'longitude': -15.3101,
#   'last_update': 1586115269000},
#  {'id': '112',
#   'country': 'Malawi',
#   'confirmed': 4,
#   'active': 4,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': -13.254308,
#   'longitude': 34.301525,
#   'last_update': 1586115269000},
#  {'id': '181',
#   'country': 'Western Sahara',
#   'confirmed': 4,
#   'active': 4,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 24.2155,
#   'longitude': -12.8858,
#   'last_update': 1586115269000},
#  {'id': '45',
#   'country': 'Burundi',
#   'confirmed': 3,
#   'active': 3,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': -3.3731,
#   'longitude': 29.9189,
#   'last_update': 1586115269000},
#  {'id': '136',
#   'country': 'Papua New Guinea',
#   'confirmed': 1,
#   'active': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': -6.314993,
#   'longitude': 143.95555,
#   'last_update': 1586115269000},
#  {'id': '159',
#   'country': 'South Sudan',
#   'confirmed': 1,
#   'active': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': 6.877,
#   'longitude': 31.307,
#   'last_update': 1586115269000},
#  {'id': '168',
#   'country': 'Timor-Leste',
#   'confirmed': 1,
#   'active': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'latitude': -8.874217,
#   'longitude': 125.727539,
#   'last_update': 1586115269000}]

# %%
covid.list_countries()
# Out:
# [{'id': '18', 'name': 'US'},
#  {'id': '160', 'name': 'Spain'},
#  {'id': '11', 'name': 'Italy'},
#  {'id': '8', 'name': 'Germany'},
#  {'id': '7', 'name': 'France'},
#  {'id': '4', 'name': 'China'},
#  {'id': '90', 'name': 'Iran'},
#  {'id': '17', 'name': 'United Kingdom'},
#  {'id': '172', 'name': 'Turkey'},
#  {'id': '16', 'name': 'Switzerland'},
#  {'id': '33', 'name': 'Belgium'},
#  {'id': '12', 'name': 'Netherlands'},
#  {'id': '3', 'name': 'Canada'},
#  {'id': '2', 'name': 'Austria'},
#  {'id': '141', 'name': 'Portugal'},
#  {'id': '40', 'name': 'Brazil'},
#  {'id': '98', 'name': 'Korea, South'},
#  {'id': '92', 'name': 'Israel'},
#  {'id': '15', 'name': 'Sweden'},
#  {'id': '1', 'name': 'Australia'},
#  {'id': '13', 'name': 'Norway'},
#  {'id': '14', 'name': 'Russia'},
#  {'id': '10', 'name': 'Ireland'},
#  {'id': '5', 'name': 'Denmark'},
#  {'id': '60', 'name': 'Czechia'},
#  {'id': '51', 'name': 'Chile'},
#  {'id': '140', 'name': 'Poland'},
#  {'id': '143', 'name': 'Romania'},
#  {'id': '113', 'name': 'Malaysia'},
#  {'id': '65', 'name': 'Ecuador'},
#  {'id': '88', 'name': 'India'},
#  {'id': '139', 'name': 'Philippines'},
#  {'id': '134', 'name': 'Pakistan'},
#  {'id': '94', 'name': 'Japan'},
#  {'id': '109', 'name': 'Luxembourg'},
#  {'id': '149', 'name': 'Saudi Arabia'},
#  {'id': '138', 'name': 'Peru'},
#  {'id': '89', 'name': 'Indonesia'},
#  {'id': '167', 'name': 'Thailand'},
#  {'id': '6', 'name': 'Finland'},
#  {'id': '151', 'name': 'Serbia'},
#  {'id': '119', 'name': 'Mexico'},
#  {'id': '135', 'name': 'Panama'},
#  {'id': '175', 'name': 'United Arab Emirates'},
#  {'id': '64', 'name': 'Dominican Republic'},
#  {'id': '78', 'name': 'Greece'},
#  {'id': '142', 'name': 'Qatar'},
#  {'id': '158', 'name': 'South Africa'},
#  {'id': '9', 'name': 'Iceland'},
#  {'id': '52', 'name': 'Colombia'},
#  {'id': '25', 'name': 'Argentina'},
#  {'id': '21', 'name': 'Algeria'},
#  {'id': '154', 'name': 'Singapore'},
#  {'id': '174', 'name': 'Ukraine'},
#  {'id': '57', 'name': 'Croatia'},
#  {'id': '66', 'name': 'Egypt'},
#  {'id': '70', 'name': 'Estonia'},
#  {'id': '128', 'name': 'New Zealand'},
#  {'id': '156', 'name': 'Slovenia'},
#  {'id': '124', 'name': 'Morocco'},
#  {'id': '91', 'name': 'Iraq'},
#  {'id': '120', 'name': 'Moldova'},
#  {'id': '26', 'name': 'Armenia'},
#  {'id': '108', 'name': 'Lithuania'},
#  {'id': '87', 'name': 'Hungary'},
#  {'id': '61', 'name': 'Diamond Princess'},
#  {'id': '29', 'name': 'Bahrain'},
#  {'id': '38', 'name': 'Bosnia and Herzegovina'},
#  {'id': '27', 'name': 'Azerbaijan'},
#  {'id': '96', 'name': 'Kazakhstan'},
#  {'id': '171', 'name': 'Tunisia'},
#  {'id': '32', 'name': 'Belarus'},
#  {'id': '100', 'name': 'Kuwait'},
#  {'id': '48', 'name': 'Cameroon'},
#  {'id': '132', 'name': 'North Macedonia'},
#  {'id': '103', 'name': 'Latvia'},
#  {'id': '42', 'name': 'Bulgaria'},
#  {'id': '104', 'name': 'Lebanon'},
#  {'id': '22', 'name': 'Andorra'},
#  {'id': '155', 'name': 'Slovakia'},
#  {'id': '55', 'name': 'Costa Rica'},
#  {'id': '59', 'name': 'Cyprus'},
#  {'id': '176', 'name': 'Uruguay'},
#  {'id': '165', 'name': 'Taiwan*'},
#  {'id': '20', 'name': 'Albania'},
#  {'id': '19', 'name': 'Afghanistan'},
#  {'id': '43', 'name': 'Burkina Faso'},
#  {'id': '95', 'name': 'Jordan'},
#  {'id': '177', 'name': 'Uzbekistan'},
#  {'id': '58', 'name': 'Cuba'},
#  {'id': '133', 'name': 'Oman'},
#  {'id': '86', 'name': 'Honduras'},
#  {'id': '148', 'name': 'San Marino'},
#  {'id': '56', 'name': "Cote d'Ivoire"},
#  {'id': '179', 'name': 'Vietnam'},
#  {'id': '180', 'name': 'West Bank and Gaza'},
#  {'id': '116', 'name': 'Malta'},
#  {'id': '118', 'name': 'Mauritius'},
#  {'id': '131', 'name': 'Nigeria'},
#  {'id': '150', 'name': 'Senegal'},
#  {'id': '77', 'name': 'Ghana'},
#  {'id': '123', 'name': 'Montenegro'},
#  {'id': '161', 'name': 'Sri Lanka'},
#  {'id': '76', 'name': 'Georgia'},
#  {'id': '178', 'name': 'Venezuela'},
#  {'id': '37', 'name': 'Bolivia'},
#  {'id': '54', 'name': 'Congo (Kinshasa)'},
#  {'id': '101', 'name': 'Kyrgyzstan'},
#  {'id': '99', 'name': 'Kosovo'},
#  {'id': '130', 'name': 'Niger'},
#  {'id': '97', 'name': 'Kenya'},
#  {'id': '41', 'name': 'Brunei'},
#  {'id': '81', 'name': 'Guinea'},
#  {'id': '47', 'name': 'Cambodia'},
#  {'id': '137', 'name': 'Paraguay'},
#  {'id': '144', 'name': 'Rwanda'},
#  {'id': '170', 'name': 'Trinidad and Tobago'},
#  {'id': '30', 'name': 'Bangladesh'},
#  {'id': '107', 'name': 'Liechtenstein'},
#  {'id': '121', 'name': 'Monaco'},
#  {'id': '111', 'name': 'Madagascar'},
#  {'id': '67', 'name': 'El Salvador'},
#  {'id': '80', 'name': 'Guatemala'},
#  {'id': '62', 'name': 'Djibouti'},
#  {'id': '31', 'name': 'Barbados'},
#  {'id': '93', 'name': 'Jamaica'},
#  {'id': '173', 'name': 'Uganda'},
#  {'id': '53', 'name': 'Congo (Brazzaville)'},
#  {'id': '115', 'name': 'Mali'},
#  {'id': '169', 'name': 'Togo'},
#  {'id': '72', 'name': 'Ethiopia'},
#  {'id': '182', 'name': 'Zambia'},
#  {'id': '69', 'name': 'Eritrea'},
#  {'id': '28', 'name': 'Bahamas'},
#  {'id': '83', 'name': 'Guyana'},
#  {'id': '35', 'name': 'Benin'},
#  {'id': '44', 'name': 'Burma'},
#  {'id': '74', 'name': 'Gabon'},
#  {'id': '84', 'name': 'Haiti'},
#  {'id': '166', 'name': 'Tanzania'},
#  {'id': '114', 'name': 'Maldives'},
#  {'id': '164', 'name': 'Syria'},
#  {'id': '82', 'name': 'Guinea-Bissau'},
#  {'id': '106', 'name': 'Libya'},
#  {'id': '68', 'name': 'Equatorial Guinea'},
#  {'id': '126', 'name': 'Namibia'},
#  {'id': '24', 'name': 'Antigua and Barbuda'},
#  {'id': '63', 'name': 'Dominica'},
#  {'id': '122', 'name': 'Mongolia'},
#  {'id': '146', 'name': 'Saint Lucia'},
#  {'id': '105', 'name': 'Liberia'},
#  {'id': '73', 'name': 'Fiji'},
#  {'id': '79', 'name': 'Grenada'},
#  {'id': '162', 'name': 'Sudan'},
#  {'id': '102', 'name': 'Laos'},
#  {'id': '23', 'name': 'Angola'},
#  {'id': '125', 'name': 'Mozambique'},
#  {'id': '145', 'name': 'Saint Kitts and Nevis'},
#  {'id': '152', 'name': 'Seychelles'},
#  {'id': '163', 'name': 'Suriname'},
#  {'id': '50', 'name': 'Chad'},
#  {'id': '71', 'name': 'Eswatini'},
#  {'id': '110', 'name': 'MS Zaandam'},
#  {'id': '127', 'name': 'Nepal'},
#  {'id': '183', 'name': 'Zimbabwe'},
#  {'id': '49', 'name': 'Central African Republic'},
#  {'id': '46', 'name': 'Cabo Verde'},
#  {'id': '85', 'name': 'Holy See'},
#  {'id': '147', 'name': 'Saint Vincent and the Grenadines'},
#  {'id': '157', 'name': 'Somalia'},
#  {'id': '39', 'name': 'Botswana'},
#  {'id': '117', 'name': 'Mauritania'},
#  {'id': '129', 'name': 'Nicaragua'},
#  {'id': '153', 'name': 'Sierra Leone'},
#  {'id': '34', 'name': 'Belize'},
#  {'id': '36', 'name': 'Bhutan'},
#  {'id': '75', 'name': 'Gambia'},
#  {'id': '112', 'name': 'Malawi'},
#  {'id': '181', 'name': 'Western Sahara'},
#  {'id': '45', 'name': 'Burundi'},
#  {'id': '136', 'name': 'Papua New Guinea'},
#  {'id': '159', 'name': 'South Sudan'},
#  {'id': '168', 'name': 'Timor-Leste'}]

# %%
covid.get_status_by_country_id(160)
# Out:
# {'id': '160',
#  'country': 'Spain',
#  'confirmed': 130854,
#  'active': 80256,
#  'deaths': 12518,
#  'recovered': 38080,
#  'latitude': 40.463667,
#  'longitude': -3.74922,
#  'last_update': 1586119517000}

# %%
covid.get_status_by_country_name('italy')
# Out:
# {'id': '11',
#  'country': 'Italy',
#  'confirmed': 128948,
#  'active': 91246,
#  'deaths': 15887,
#  'recovered': 21815,
#  'latitude': 41.8719,
#  'longitude': 12.5674,
#  'last_update': 1586115269000}

# %%
covid.get_total_active_cases()
# Out:
# 617052

# %%
covid.get_total_confirmed_cases()
# Out:
# 1260104

# %%
covid.get_total_recovered()
# Out:
# 258588

# %%
covid.get_total_deaths()
# Out:
# 68413

# %%
covid=Covid(source='worldometers')

# %%
covid.get_data()
# Out:
# [{'country': 'World',
#   'confirmed': 1266782,
#   'new_cases': 65329,
#   'deaths': 69177,
#   'recovered': 261132,
#   'active': 936473,
#   'critical': 45532,
#   'new_deaths': 4489,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('163'),
#   'total_deaths_per_million': Decimal('8.9')},
#  {'country': 'USA',
#   'confirmed': 333173,
#   'new_cases': 21816,
#   'deaths': 9536,
#   'recovered': 17177,
#   'active': 306460,
#   'critical': 8623,
#   'new_deaths': 1084,
#   'total_tests': 1751296,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1007'),
#   'total_deaths_per_million': Decimal('29')},
#  {'country': 'Spain',
#   'confirmed': 130854,
#   'new_cases': 4686,
#   'deaths': 12518,
#   'recovered': 38080,
#   'active': 80256,
#   'critical': 6861,
#   'new_deaths': 571,
#   'total_tests': 355000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2799'),
#   'total_deaths_per_million': Decimal('268')},
#  {'country': 'Italy',
#   'confirmed': 128948,
#   'new_cases': 4316,
#   'deaths': 15887,
#   'recovered': 21815,
#   'active': 91246,
#   'critical': 3977,
#   'new_deaths': 525,
#   'total_tests': 691461,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2133'),
#   'total_deaths_per_million': Decimal('263')},
#  {'country': 'Germany',
#   'confirmed': 100024,
#   'new_cases': 3932,
#   'deaths': 1576,
#   'recovered': 28700,
#   'active': 69748,
#   'critical': 3936,
#   'new_deaths': 132,
#   'total_tests': 918460,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1194'),
#   'total_deaths_per_million': Decimal('19')},
#  {'country': 'France',
#   'confirmed': 92839,
#   'new_cases': 2886,
#   'deaths': 8078,
#   'recovered': 16183,
#   'active': 68578,
#   'critical': 6838,
#   'new_deaths': 518,
#   'total_tests': 224254,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1422'),
#   'total_deaths_per_million': Decimal('124')},
#  {'country': 'Iran',
#   'confirmed': 58226,
#   'new_cases': 2483,
#   'deaths': 3603,
#   'recovered': 19736,
#   'active': 34887,
#   'critical': 4103,
#   'new_deaths': 151,
#   'total_tests': 186000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('693'),
#   'total_deaths_per_million': Decimal('43')},
#  {'country': 'UK',
#   'confirmed': 47806,
#   'new_cases': 5903,
#   'deaths': 4934,
#   'recovered': 135,
#   'active': 42737,
#   'critical': 1559,
#   'new_deaths': 621,
#   'total_tests': 195524,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('704'),
#   'total_deaths_per_million': Decimal('73')},
#  {'country': 'Turkey',
#   'confirmed': 27069,
#   'new_cases': 3135,
#   'deaths': 574,
#   'recovered': 1042,
#   'active': 25453,
#   'critical': 1381,
#   'new_deaths': 73,
#   'total_tests': 181445,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('321'),
#   'total_deaths_per_million': Decimal('7')},
#  {'country': 'Switzerland',
#   'confirmed': 21100,
#   'new_cases': 595,
#   'deaths': 715,
#   'recovered': 6415,
#   'active': 13970,
#   'critical': 391,
#   'new_deaths': 49,
#   'total_tests': 158000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2438'),
#   'total_deaths_per_million': Decimal('83')},
#  {'country': 'Belgium',
#   'confirmed': 19691,
#   'new_cases': 1260,
#   'deaths': 1447,
#   'recovered': 3751,
#   'active': 14493,
#   'critical': 1261,
#   'new_deaths': 164,
#   'total_tests': 70000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1699'),
#   'total_deaths_per_million': Decimal('125')},
#  {'country': 'Netherlands',
#   'confirmed': 17851,
#   'new_cases': 1224,
#   'deaths': 1766,
#   'recovered': 250,
#   'active': 15835,
#   'critical': 1385,
#   'new_deaths': 115,
#   'total_tests': 75415,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1042'),
#   'total_deaths_per_million': Decimal('103')},
#  {'country': 'Canada',
#   'confirmed': 15425,
#   'new_cases': 1513,
#   'deaths': 277,
#   'recovered': 2847,
#   'active': 12301,
#   'critical': 426,
#   'new_deaths': 46,
#   'total_tests': 317972,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('409'),
#   'total_deaths_per_million': Decimal('7')},
#  {'country': 'Austria',
#   'confirmed': 12051,
#   'new_cases': 270,
#   'deaths': 204,
#   'recovered': 2998,
#   'active': 8849,
#   'critical': 244,
#   'new_deaths': 18,
#   'total_tests': 108416,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1338'),
#   'total_deaths_per_million': Decimal('23')},
#  {'country': 'Portugal',
#   'confirmed': 11278,
#   'new_cases': 754,
#   'deaths': 295,
#   'recovered': 75,
#   'active': 10908,
#   'critical': 267,
#   'new_deaths': 29,
#   'total_tests': 86370,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1106'),
#   'total_deaths_per_million': Decimal('29')},
#  {'country': 'Brazil',
#   'confirmed': 11130,
#   'new_cases': 770,
#   'deaths': 486,
#   'recovered': 127,
#   'active': 10517,
#   'critical': 296,
#   'new_deaths': 41,
#   'total_tests': 54824,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('52'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'S. Korea',
#   'confirmed': 10237,
#   'new_cases': 81,
#   'deaths': 183,
#   'recovered': 6463,
#   'active': 3591,
#   'critical': 55,
#   'new_deaths': 6,
#   'total_tests': 461233,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('200'),
#   'total_deaths_per_million': Decimal('4')},
#  {'country': 'Israel',
#   'confirmed': 8430,
#   'new_cases': 579,
#   'deaths': 49,
#   'recovered': 477,
#   'active': 7904,
#   'critical': 139,
#   'new_deaths': 5,
#   'total_tests': 90394,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('974'),
#   'total_deaths_per_million': Decimal('6')},
#  {'country': 'Sweden',
#   'confirmed': 6830,
#   'new_cases': 387,
#   'deaths': 401,
#   'recovered': 205,
#   'active': 6224,
#   'critical': 541,
#   'new_deaths': 28,
#   'total_tests': 36900,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('676'),
#   'total_deaths_per_million': Decimal('40')},
#  {'country': 'Norway',
#   'confirmed': 5687,
#   'new_cases': 137,
#   'deaths': 71,
#   'recovered': 32,
#   'active': 5584,
#   'critical': 89,
#   'new_deaths': 9,
#   'total_tests': 105865,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1049'),
#   'total_deaths_per_million': Decimal('13')},
#  {'country': 'Australia',
#   'confirmed': 5687,
#   'new_cases': 137,
#   'deaths': 35,
#   'recovered': 2315,
#   'active': 3337,
#   'critical': 91,
#   'new_deaths': 5,
#   'total_tests': 297154,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('223'),
#   'total_deaths_per_million': Decimal('1')},
#  {'country': 'Russia',
#   'confirmed': 5389,
#   'new_cases': 658,
#   'deaths': 45,
#   'recovered': 355,
#   'active': 4989,
#   'critical': 8,
#   'new_deaths': 2,
#   'total_tests': 697000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('37'),
#   'total_deaths_per_million': Decimal('0.3')},
#  {'country': 'Ireland',
#   'confirmed': 4994,
#   'new_cases': 390,
#   'deaths': 158,
#   'recovered': 25,
#   'active': 4811,
#   'critical': 165,
#   'new_deaths': 21,
#   'total_tests': 30213,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1011'),
#   'total_deaths_per_million': Decimal('32')},
#  {'country': 'Czechia',
#   'confirmed': 4543,
#   'new_cases': 71,
#   'deaths': 67,
#   'recovered': 96,
#   'active': 4380,
#   'critical': 86,
#   'new_deaths': 8,
#   'total_tests': 80304,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('424'),
#   'total_deaths_per_million': Decimal('6')},
#  {'country': 'Chile',
#   'confirmed': 4471,
#   'new_cases': 310,
#   'deaths': 34,
#   'recovered': 618,
#   'active': 3819,
#   'critical': 307,
#   'new_deaths': 7,
#   'total_tests': 51956,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('234'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Denmark',
#   'confirmed': 4369,
#   'new_cases': 292,
#   'deaths': 179,
#   'recovered': 1327,
#   'active': 2863,
#   'critical': 142,
#   'new_deaths': 18,
#   'total_tests': 49249,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('754'),
#   'total_deaths_per_million': Decimal('31')},
#  {'country': 'Poland',
#   'confirmed': 4102,
#   'new_cases': 475,
#   'deaths': 94,
#   'recovered': 134,
#   'active': 3874,
#   'critical': 50,
#   'new_deaths': 15,
#   'total_tests': 80757,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('108'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Romania',
#   'confirmed': 3864,
#   'new_cases': 251,
#   'deaths': 151,
#   'recovered': 374,
#   'active': 3339,
#   'critical': 141,
#   'new_deaths': 5,
#   'total_tests': 38623,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('201'),
#   'total_deaths_per_million': Decimal('8')},
#  {'country': 'Malaysia',
#   'confirmed': 3662,
#   'new_cases': 179,
#   'deaths': 61,
#   'recovered': 1005,
#   'active': 2596,
#   'critical': 99,
#   'new_deaths': 4,
#   'total_tests': 51937,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('113'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Ecuador',
#   'confirmed': 3646,
#   'new_cases': 181,
#   'deaths': 180,
#   'recovered': 100,
#   'active': 3366,
#   'critical': 100,
#   'new_deaths': 8,
#   'total_tests': 12386,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('207'),
#   'total_deaths_per_million': Decimal('10')},
#  {'country': 'India',
#   'confirmed': 3588,
#   'new_cases': 0,
#   'deaths': 99,
#   'recovered': 229,
#   'active': 3260,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 128320,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0.07')},
#  {'country': 'Philippines',
#   'confirmed': 3246,
#   'new_cases': 152,
#   'deaths': 152,
#   'recovered': 64,
#   'active': 3030,
#   'critical': 1,
#   'new_deaths': 8,
#   'total_tests': 19585,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('30'),
#   'total_deaths_per_million': Decimal('1')},
#  {'country': 'Pakistan',
#   'confirmed': 3157,
#   'new_cases': 339,
#   'deaths': 47,
#   'recovered': 211,
#   'active': 2899,
#   'critical': 18,
#   'new_deaths': 6,
#   'total_tests': 34885,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('14'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Japan',
#   'confirmed': 3139,
#   'new_cases': 0,
#   'deaths': 77,
#   'recovered': 514,
#   'active': 2548,
#   'critical': 64,
#   'new_deaths': 0,
#   'total_tests': 44639,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('25'),
#   'total_deaths_per_million': Decimal('0.6')},
#  {'country': 'Luxembourg',
#   'confirmed': 2804,
#   'new_cases': 75,
#   'deaths': 36,
#   'recovered': 500,
#   'active': 2268,
#   'critical': 33,
#   'new_deaths': 5,
#   'total_tests': 23687,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4479'),
#   'total_deaths_per_million': Decimal('58')},
#  {'country': 'Saudi Arabia',
#   'confirmed': 2402,
#   'new_cases': 223,
#   'deaths': 34,
#   'recovered': 488,
#   'active': 1880,
#   'critical': 41,
#   'new_deaths': 5,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69'),
#   'total_deaths_per_million': Decimal('1.0')},
#  {'country': 'Peru',
#   'confirmed': 2281,
#   'new_cases': 535,
#   'deaths': 83,
#   'recovered': 989,
#   'active': 1209,
#   'critical': 81,
#   'new_deaths': 10,
#   'total_tests': 19410,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69'),
#   'total_deaths_per_million': Decimal('3')},
#  {'country': 'Indonesia',
#   'confirmed': 2273,
#   'new_cases': 181,
#   'deaths': 198,
#   'recovered': 164,
#   'active': 1911,
#   'critical': 0,
#   'new_deaths': 7,
#   'total_tests': 9712,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0.7')},
#  {'country': 'Thailand',
#   'confirmed': 2169,
#   'new_cases': 102,
#   'deaths': 23,
#   'recovered': 793,
#   'active': 1353,
#   'critical': 23,
#   'new_deaths': 3,
#   'total_tests': 25071,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('31'),
#   'total_deaths_per_million': Decimal('0.3')},
#  {'country': 'Finland',
#   'confirmed': 1927,
#   'new_cases': 45,
#   'deaths': 28,
#   'recovered': 300,
#   'active': 1599,
#   'critical': 73,
#   'new_deaths': 3,
#   'total_tests': 31714,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('348'),
#   'total_deaths_per_million': Decimal('5')},
#  {'country': 'Serbia',
#   'confirmed': 1908,
#   'new_cases': 284,
#   'deaths': 51,
#   'recovered': 54,
#   'active': 1803,
#   'critical': 98,
#   'new_deaths': 7,
#   'total_tests': 7360,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('218'),
#   'total_deaths_per_million': Decimal('6')},
#  {'country': 'Mexico',
#   'confirmed': 1890,
#   'new_cases': 202,
#   'deaths': 79,
#   'recovered': 633,
#   'active': 1178,
#   'critical': 1,
#   'new_deaths': 19,
#   'total_tests': 15668,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15'),
#   'total_deaths_per_million': Decimal('0.6')},
#  {'country': 'Panama',
#   'confirmed': 1801,
#   'new_cases': 0,
#   'deaths': 46,
#   'recovered': 13,
#   'active': 1742,
#   'critical': 75,
#   'new_deaths': 0,
#   'total_tests': 9256,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('417'),
#   'total_deaths_per_million': Decimal('11')},
#  {'country': 'UAE',
#   'confirmed': 1799,
#   'new_cases': 294,
#   'deaths': 10,
#   'recovered': 144,
#   'active': 1645,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 220000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('182'),
#   'total_deaths_per_million': Decimal('1')},
#  {'country': 'Dominican Republic',
#   'confirmed': 1745,
#   'new_cases': 167,
#   'deaths': 82,
#   'recovered': 17,
#   'active': 1646,
#   'critical': 147,
#   'new_deaths': 5,
#   'total_tests': 4542,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('161'),
#   'total_deaths_per_million': Decimal('8')},
#  {'country': 'Greece',
#   'confirmed': 1735,
#   'new_cases': 62,
#   'deaths': 73,
#   'recovered': 78,
#   'active': 1584,
#   'critical': 93,
#   'new_deaths': 5,
#   'total_tests': 25453,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('166'),
#   'total_deaths_per_million': Decimal('7')},
#  {'country': 'South Africa',
#   'confirmed': 1655,
#   'new_cases': 70,
#   'deaths': 11,
#   'recovered': 95,
#   'active': 1549,
#   'critical': 7,
#   'new_deaths': 2,
#   'total_tests': 56873,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('28'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Qatar',
#   'confirmed': 1604,
#   'new_cases': 279,
#   'deaths': 4,
#   'recovered': 123,
#   'active': 1477,
#   'critical': 37,
#   'new_deaths': 1,
#   'total_tests': 35757,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('557'),
#   'total_deaths_per_million': Decimal('1')},
#  {'country': 'Iceland',
#   'confirmed': 1486,
#   'new_cases': 69,
#   'deaths': 4,
#   'recovered': 428,
#   'active': 1054,
#   'critical': 11,
#   'new_deaths': 0,
#   'total_tests': 25394,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4355'),
#   'total_deaths_per_million': Decimal('12')},
#  {'country': 'Colombia',
#   'confirmed': 1485,
#   'new_cases': 79,
#   'deaths': 35,
#   'recovered': 88,
#   'active': 1362,
#   'critical': 50,
#   'new_deaths': 3,
#   'total_tests': 23706,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('29'),
#   'total_deaths_per_million': Decimal('0.7')},
#  {'country': 'Argentina',
#   'confirmed': 1451,
#   'new_cases': 0,
#   'deaths': 44,
#   'recovered': 280,
#   'active': 1127,
#   'critical': 86,
#   'new_deaths': 1,
#   'total_tests': 8488,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('32'),
#   'total_deaths_per_million': Decimal('1.0')},
#  {'country': 'Algeria',
#   'confirmed': 1320,
#   'new_cases': 69,
#   'deaths': 152,
#   'recovered': 90,
#   'active': 1078,
#   'critical': 46,
#   'new_deaths': 22,
#   'total_tests': 3359,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('30'),
#   'total_deaths_per_million': Decimal('3')},
#  {'country': 'Singapore',
#   'confirmed': 1309,
#   'new_cases': 120,
#   'deaths': 6,
#   'recovered': 320,
#   'active': 983,
#   'critical': 25,
#   'new_deaths': 0,
#   'total_tests': 39000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('224'),
#   'total_deaths_per_million': Decimal('1')},
#  {'country': 'Ukraine',
#   'confirmed': 1308,
#   'new_cases': 83,
#   'deaths': 37,
#   'recovered': 28,
#   'active': 1243,
#   'critical': 16,
#   'new_deaths': 5,
#   'total_tests': 5493,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('30'),
#   'total_deaths_per_million': Decimal('0.8')},
#  {'country': 'Croatia',
#   'confirmed': 1182,
#   'new_cases': 56,
#   'deaths': 15,
#   'recovered': 125,
#   'active': 1042,
#   'critical': 39,
#   'new_deaths': 3,
#   'total_tests': 10847,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('288'),
#   'total_deaths_per_million': Decimal('4')},
#  {'country': 'Egypt',
#   'confirmed': 1173,
#   'new_cases': 103,
#   'deaths': 78,
#   'recovered': 247,
#   'active': 848,
#   'critical': 0,
#   'new_deaths': 7,
#   'total_tests': 25000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11'),
#   'total_deaths_per_million': Decimal('0.8')},
#  {'country': 'Estonia',
#   'confirmed': 1097,
#   'new_cases': 58,
#   'deaths': 15,
#   'recovered': 62,
#   'active': 1020,
#   'critical': 17,
#   'new_deaths': 2,
#   'total_tests': 21004,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('827'),
#   'total_deaths_per_million': Decimal('11')},
#  {'country': 'New Zealand',
#   'confirmed': 1039,
#   'new_cases': 89,
#   'deaths': 1,
#   'recovered': 156,
#   'active': 882,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 36209,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('215'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Morocco',
#   'confirmed': 1021,
#   'new_cases': 102,
#   'deaths': 70,
#   'recovered': 76,
#   'active': 875,
#   'critical': 1,
#   'new_deaths': 11,
#   'total_tests': 4848,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('28'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Slovenia',
#   'confirmed': 997,
#   'new_cases': 20,
#   'deaths': 28,
#   'recovered': 79,
#   'active': 890,
#   'critical': 31,
#   'new_deaths': 6,
#   'total_tests': 27764,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('480'),
#   'total_deaths_per_million': Decimal('13')},
#  {'country': 'Iraq',
#   'confirmed': 961,
#   'new_cases': 83,
#   'deaths': 61,
#   'recovered': 279,
#   'active': 621,
#   'critical': 0,
#   'new_deaths': 5,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('24'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Hong Kong',
#   'confirmed': 890,
#   'new_cases': 28,
#   'deaths': 4,
#   'recovered': 206,
#   'active': 680,
#   'critical': 8,
#   'new_deaths': 0,
#   'total_tests': 96709,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('119'),
#   'total_deaths_per_million': Decimal('0.5')},
#  {'country': 'Moldova',
#   'confirmed': 864,
#   'new_cases': 112,
#   'deaths': 15,
#   'recovered': 30,
#   'active': 819,
#   'critical': 80,
#   'new_deaths': 3,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('214'),
#   'total_deaths_per_million': Decimal('4')},
#  {'country': 'Armenia',
#   'confirmed': 822,
#   'new_cases': 52,
#   'deaths': 7,
#   'recovered': 57,
#   'active': 758,
#   'critical': 30,
#   'new_deaths': 0,
#   'total_tests': 4666,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('277'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Lithuania',
#   'confirmed': 811,
#   'new_cases': 40,
#   'deaths': 13,
#   'recovered': 7,
#   'active': 791,
#   'critical': 11,
#   'new_deaths': 2,
#   'total_tests': 23645,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('298'),
#   'total_deaths_per_million': Decimal('5')},
#  {'country': 'Hungary',
#   'confirmed': 733,
#   'new_cases': 55,
#   'deaths': 34,
#   'recovered': 66,
#   'active': 633,
#   'critical': 17,
#   'new_deaths': 2,
#   'total_tests': 21250,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('76'),
#   'total_deaths_per_million': Decimal('4')},
#  {'country': 'Diamond Princess',
#   'confirmed': 712,
#   'new_cases': 0,
#   'deaths': 11,
#   'recovered': 619,
#   'active': 82,
#   'critical': 10,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Bahrain',
#   'confirmed': 700,
#   'new_cases': 12,
#   'deaths': 4,
#   'recovered': 431,
#   'active': 265,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 44386,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('411'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Bosnia and Herzegovina',
#   'confirmed': 654,
#   'new_cases': 30,
#   'deaths': 23,
#   'recovered': 30,
#   'active': 601,
#   'critical': 4,
#   'new_deaths': 2,
#   'total_tests': 5349,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('199'),
#   'total_deaths_per_million': Decimal('7')},
#  {'country': 'Cameroon',
#   'confirmed': 650,
#   'new_cases': 95,
#   'deaths': 9,
#   'recovered': 17,
#   'active': 624,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('24'),
#   'total_deaths_per_million': Decimal('0.3')},
#  {'country': 'Azerbaijan',
#   'confirmed': 584,
#   'new_cases': 63,
#   'deaths': 7,
#   'recovered': 32,
#   'active': 545,
#   'critical': 17,
#   'new_deaths': 2,
#   'total_tests': 40000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58'),
#   'total_deaths_per_million': Decimal('0.7')},
#  {'country': 'Kazakhstan',
#   'confirmed': 584,
#   'new_cases': 53,
#   'deaths': 6,
#   'recovered': 42,
#   'active': 536,
#   'critical': 6,
#   'new_deaths': 1,
#   'total_tests': 5093,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('31'),
#   'total_deaths_per_million': Decimal('0.3')},
#  {'country': 'Tunisia',
#   'confirmed': 574,
#   'new_cases': 21,
#   'deaths': 22,
#   'recovered': 5,
#   'active': 547,
#   'critical': 39,
#   'new_deaths': 4,
#   'total_tests': 7145,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('49'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Belarus',
#   'confirmed': 562,
#   'new_cases': 122,
#   'deaths': 8,
#   'recovered': 52,
#   'active': 502,
#   'critical': 11,
#   'new_deaths': 3,
#   'total_tests': 32000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('59'),
#   'total_deaths_per_million': Decimal('0.8')},
#  {'country': 'Kuwait',
#   'confirmed': 556,
#   'new_cases': 77,
#   'deaths': 1,
#   'recovered': 99,
#   'active': 456,
#   'critical': 17,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('130'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'North Macedonia',
#   'confirmed': 555,
#   'new_cases': 72,
#   'deaths': 18,
#   'recovered': 23,
#   'active': 514,
#   'critical': 15,
#   'new_deaths': 1,
#   'total_tests': 4920,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('266'),
#   'total_deaths_per_million': Decimal('9')},
#  {'country': 'Latvia',
#   'confirmed': 533,
#   'new_cases': 24,
#   'deaths': 1,
#   'recovered': 1,
#   'active': 531,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 20680,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('283'),
#   'total_deaths_per_million': Decimal('0.5')},
#  {'country': 'Bulgaria',
#   'confirmed': 531,
#   'new_cases': 28,
#   'deaths': 20,
#   'recovered': 37,
#   'active': 474,
#   'critical': 22,
#   'new_deaths': 3,
#   'total_tests': 15899,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('76'),
#   'total_deaths_per_million': Decimal('3')},
#  {'country': 'Lebanon',
#   'confirmed': 527,
#   'new_cases': 7,
#   'deaths': 18,
#   'recovered': 54,
#   'active': 455,
#   'critical': 28,
#   'new_deaths': 1,
#   'total_tests': 9411,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('77'),
#   'total_deaths_per_million': Decimal('3')},
#  {'country': 'Andorra',
#   'confirmed': 501,
#   'new_cases': 35,
#   'deaths': 18,
#   'recovered': 26,
#   'active': 457,
#   'critical': 12,
#   'new_deaths': 1,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6484'),
#   'total_deaths_per_million': Decimal('233')},
#  {'country': 'Slovakia',
#   'confirmed': 485,
#   'new_cases': 14,
#   'deaths': 1,
#   'recovered': 10,
#   'active': 474,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 15155,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('89'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Costa Rica',
#   'confirmed': 454,
#   'new_cases': 19,
#   'deaths': 2,
#   'recovered': 16,
#   'active': 436,
#   'critical': 14,
#   'new_deaths': 0,
#   'total_tests': 5098,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('89'),
#   'total_deaths_per_million': Decimal('0.4')},
#  {'country': 'Cyprus',
#   'confirmed': 446,
#   'new_cases': 20,
#   'deaths': 9,
#   'recovered': 37,
#   'active': 400,
#   'critical': 11,
#   'new_deaths': 0,
#   'total_tests': 10946,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('369'),
#   'total_deaths_per_million': Decimal('7')},
#  {'country': 'Uruguay',
#   'confirmed': 400,
#   'new_cases': 0,
#   'deaths': 5,
#   'recovered': 93,
#   'active': 302,
#   'critical': 13,
#   'new_deaths': 0,
#   'total_tests': 5063,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('115'),
#   'total_deaths_per_million': Decimal('1')},
#  {'country': 'Taiwan',
#   'confirmed': 363,
#   'new_cases': 8,
#   'deaths': 5,
#   'recovered': 54,
#   'active': 304,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 37219,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Albania',
#   'confirmed': 361,
#   'new_cases': 28,
#   'deaths': 20,
#   'recovered': 104,
#   'active': 237,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 2396,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('125'),
#   'total_deaths_per_million': Decimal('7')},
#  {'country': 'Afghanistan',
#   'confirmed': 349,
#   'new_cases': 40,
#   'deaths': 7,
#   'recovered': 15,
#   'active': 327,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Burkina Faso',
#   'confirmed': 345,
#   'new_cases': 27,
#   'deaths': 17,
#   'recovered': 90,
#   'active': 238,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17'),
#   'total_deaths_per_million': Decimal('0.8')},
#  {'country': 'Jordan',
#   'confirmed': 345,
#   'new_cases': 22,
#   'deaths': 5,
#   'recovered': 110,
#   'active': 230,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('34'),
#   'total_deaths_per_million': Decimal('0.5')},
#  {'country': 'Réunion',
#   'confirmed': 344,
#   'new_cases': 10,
#   'deaths': 0,
#   'recovered': 40,
#   'active': 304,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('384'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Uzbekistan',
#   'confirmed': 342,
#   'new_cases': 76,
#   'deaths': 2,
#   'recovered': 30,
#   'active': 310,
#   'critical': 8,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10'),
#   'total_deaths_per_million': Decimal('0.06')},
#  {'country': 'Cuba',
#   'confirmed': 320,
#   'new_cases': 32,
#   'deaths': 8,
#   'recovered': 15,
#   'active': 297,
#   'critical': 11,
#   'new_deaths': 2,
#   'total_tests': 5234,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('28'),
#   'total_deaths_per_million': Decimal('0.7')},
#  {'country': 'Channel Islands',
#   'confirmed': 309,
#   'new_cases': 47,
#   'deaths': 6,
#   'recovered': 27,
#   'active': 276,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1777'),
#   'total_deaths_per_million': Decimal('35')},
#  {'country': 'Oman',
#   'confirmed': 298,
#   'new_cases': 21,
#   'deaths': 2,
#   'recovered': 61,
#   'active': 235,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58'),
#   'total_deaths_per_million': Decimal('0.4')},
#  {'country': 'Honduras',
#   'confirmed': 268,
#   'new_cases': 4,
#   'deaths': 22,
#   'recovered': 6,
#   'active': 240,
#   'critical': 10,
#   'new_deaths': 7,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('27'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'San Marino',
#   'confirmed': 266,
#   'new_cases': 7,
#   'deaths': 32,
#   'recovered': 35,
#   'active': 199,
#   'critical': 14,
#   'new_deaths': 0,
#   'total_tests': 586,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7839'),
#   'total_deaths_per_million': Decimal('943')},
#  {'country': 'Ivory Coast',
#   'confirmed': 261,
#   'new_cases': 16,
#   'deaths': 3,
#   'recovered': 37,
#   'active': 221,
#   'critical': 0,
#   'new_deaths': 2,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10'),
#   'total_deaths_per_million': Decimal('0.1')},
#  {'country': 'Vietnam',
#   'confirmed': 241,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 90,
#   'active': 151,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 88551,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Palestine',
#   'confirmed': 234,
#   'new_cases': 17,
#   'deaths': 1,
#   'recovered': 23,
#   'active': 210,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 12738,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('46'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Nigeria',
#   'confirmed': 232,
#   'new_cases': 18,
#   'deaths': 5,
#   'recovered': 33,
#   'active': 194,
#   'critical': 2,
#   'new_deaths': 1,
#   'total_tests': 4000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1'),
#   'total_deaths_per_million': Decimal('0.02')},
#  {'country': 'Mauritius',
#   'confirmed': 227,
#   'new_cases': 31,
#   'deaths': 7,
#   'recovered': 7,
#   'active': 213,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('178'),
#   'total_deaths_per_million': Decimal('6')},
#  {'country': 'Malta',
#   'confirmed': 227,
#   'new_cases': 14,
#   'deaths': 0,
#   'recovered': 5,
#   'active': 222,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 10358,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('514'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Senegal',
#   'confirmed': 222,
#   'new_cases': 3,
#   'deaths': 2,
#   'recovered': 82,
#   'active': 138,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13'),
#   'total_deaths_per_million': Decimal('0.1')},
#  {'country': 'Ghana',
#   'confirmed': 214,
#   'new_cases': 9,
#   'deaths': 5,
#   'recovered': 31,
#   'active': 178,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Montenegro',
#   'confirmed': 214,
#   'new_cases': 13,
#   'deaths': 2,
#   'recovered': 1,
#   'active': 211,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 1583,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('341'),
#   'total_deaths_per_million': Decimal('3')},
#  {'country': 'Niger',
#   'confirmed': 184,
#   'new_cases': 40,
#   'deaths': 10,
#   'recovered': 13,
#   'active': 161,
#   'critical': 0,
#   'new_deaths': 2,
#   'total_tests': 4012,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0.4')},
#  {'country': 'Faeroe Islands',
#   'confirmed': 181,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 99,
#   'active': 82,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 4890,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3704'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Sri Lanka',
#   'confirmed': 176,
#   'new_cases': 10,
#   'deaths': 5,
#   'recovered': 33,
#   'active': 138,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Georgia',
#   'confirmed': 174,
#   'new_cases': 12,
#   'deaths': 2,
#   'recovered': 36,
#   'active': 136,
#   'critical': 6,
#   'new_deaths': 1,
#   'total_tests': 2762,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('44'),
#   'total_deaths_per_million': Decimal('0.5')},
#  {'country': 'Venezuela',
#   'confirmed': 159,
#   'new_cases': 4,
#   'deaths': 7,
#   'recovered': 52,
#   'active': 100,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 1779,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Bolivia',
#   'confirmed': 157,
#   'new_cases': 18,
#   'deaths': 10,
#   'recovered': 2,
#   'active': 145,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 591,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13'),
#   'total_deaths_per_million': Decimal('0.9')},
#  {'country': 'DRC',
#   'confirmed': 154,
#   'new_cases': 0,
#   'deaths': 18,
#   'recovered': 3,
#   'active': 133,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Martinique',
#   'confirmed': 149,
#   'new_cases': 4,
#   'deaths': 4,
#   'recovered': 50,
#   'active': 95,
#   'critical': 21,
#   'new_deaths': 1,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('397'),
#   'total_deaths_per_million': Decimal('11')},
#  {'country': 'Kyrgyzstan',
#   'confirmed': 147,
#   'new_cases': 3,
#   'deaths': 1,
#   'recovered': 9,
#   'active': 137,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 9618,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('23'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Kenya',
#   'confirmed': 142,
#   'new_cases': 16,
#   'deaths': 4,
#   'recovered': 4,
#   'active': 134,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 3836,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0.07')},
#  {'country': 'Brunei',
#   'confirmed': 135,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 73,
#   'active': 61,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 8129,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('309'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Guadeloupe',
#   'confirmed': 134,
#   'new_cases': 0,
#   'deaths': 7,
#   'recovered': 24,
#   'active': 103,
#   'critical': 14,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('335'),
#   'total_deaths_per_million': Decimal('17')},
#  {'country': 'Mayotte',
#   'confirmed': 134,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 14,
#   'active': 118,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 479,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('491'),
#   'total_deaths_per_million': Decimal('7')},
#  {'country': 'Isle of Man',
#   'confirmed': 127,
#   'new_cases': 1,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 126,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1334,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1494'),
#   'total_deaths_per_million': Decimal('12')},
#  {'country': 'Guinea',
#   'confirmed': 121,
#   'new_cases': 10,
#   'deaths': 0,
#   'recovered': 5,
#   'active': 116,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Cambodia',
#   'confirmed': 114,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 50,
#   'active': 64,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 5768,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Trinidad and Tobago',
#   'confirmed': 104,
#   'new_cases': 1,
#   'deaths': 7,
#   'recovered': 1,
#   'active': 96,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 797,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('74'),
#   'total_deaths_per_million': Decimal('5')},
#  {'country': 'Paraguay',
#   'confirmed': 104,
#   'new_cases': 8,
#   'deaths': 3,
#   'recovered': 12,
#   'active': 89,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 1381,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15'),
#   'total_deaths_per_million': Decimal('0.4')},
#  {'country': 'Rwanda',
#   'confirmed': 104,
#   'new_cases': 2,
#   'deaths': 0,
#   'recovered': 4,
#   'active': 100,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Gibraltar',
#   'confirmed': 103,
#   'new_cases': 5,
#   'deaths': 0,
#   'recovered': 52,
#   'active': 51,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1345,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3057'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Bangladesh',
#   'confirmed': 88,
#   'new_cases': 18,
#   'deaths': 9,
#   'recovered': 33,
#   'active': 46,
#   'critical': 1,
#   'new_deaths': 1,
#   'total_tests': 2086,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.5'),
#   'total_deaths_per_million': Decimal('0.05')},
#  {'country': 'Liechtenstein',
#   'confirmed': 77,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 76,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 900,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2020'),
#   'total_deaths_per_million': Decimal('26')},
#  {'country': 'Monaco',
#   'confirmed': 73,
#   'new_cases': 7,
#   'deaths': 1,
#   'recovered': 3,
#   'active': 69,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1860'),
#   'total_deaths_per_million': Decimal('25')},
#  {'country': 'Madagascar',
#   'confirmed': 72,
#   'new_cases': 2,
#   'deaths': 0,
#   'recovered': 2,
#   'active': 70,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Aruba',
#   'confirmed': 64,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 63,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 863,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('599'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'El Salvador',
#   'confirmed': 62,
#   'new_cases': 6,
#   'deaths': 3,
#   'recovered': 2,
#   'active': 57,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10'),
#   'total_deaths_per_million': Decimal('0.5')},
#  {'country': 'Guatemala',
#   'confirmed': 61,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 15,
#   'active': 44,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 1134,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0.1')},
#  {'country': 'French Guiana',
#   'confirmed': 61,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 22,
#   'active': 39,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('204'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Djibouti',
#   'confirmed': 59,
#   'new_cases': 9,
#   'deaths': 0,
#   'recovered': 9,
#   'active': 50,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('60'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Barbados',
#   'confirmed': 56,
#   'new_cases': 4,
#   'deaths': 1,
#   'recovered': 6,
#   'active': 49,
#   'critical': 4,
#   'new_deaths': 1,
#   'total_tests': 527,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('195'),
#   'total_deaths_per_million': Decimal('3')},
#  {'country': 'Jamaica',
#   'confirmed': 55,
#   'new_cases': 2,
#   'deaths': 3,
#   'recovered': 7,
#   'active': 45,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 540,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('19'),
#   'total_deaths_per_million': Decimal('1')},
#  {'country': 'Uganda',
#   'confirmed': 52,
#   'new_cases': 4,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 52,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2629,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Congo',
#   'confirmed': 45,
#   'new_cases': 23,
#   'deaths': 5,
#   'recovered': 2,
#   'active': 38,
#   'critical': 0,
#   'new_deaths': 3,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0.9')},
#  {'country': 'Mali',
#   'confirmed': 45,
#   'new_cases': 4,
#   'deaths': 5,
#   'recovered': 1,
#   'active': 39,
#   'critical': 0,
#   'new_deaths': 2,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Togo',
#   'confirmed': 44,
#   'new_cases': 3,
#   'deaths': 3,
#   'recovered': 20,
#   'active': 21,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5'),
#   'total_deaths_per_million': Decimal('0.4')},
#  {'country': 'Macao',
#   'confirmed': 44,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 10,
#   'active': 34,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('68'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Ethiopia',
#   'confirmed': 43,
#   'new_cases': 5,
#   'deaths': 2,
#   'recovered': 4,
#   'active': 37,
#   'critical': 1,
#   'new_deaths': 2,
#   'total_tests': 1843,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.4'),
#   'total_deaths_per_million': Decimal('0.02')},
#  {'country': 'French Polynesia',
#   'confirmed': 41,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 41,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 612,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('146'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Zambia',
#   'confirmed': 39,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 3,
#   'active': 35,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 619,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0.05')},
#  {'country': 'Bermuda',
#   'confirmed': 37,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 14,
#   'active': 23,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 291,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('594'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Cayman Islands',
#   'confirmed': 35,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 1,
#   'active': 33,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 319,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('533'),
#   'total_deaths_per_million': Decimal('15')},
#  {'country': 'Saint Martin',
#   'confirmed': 32,
#   'new_cases': 8,
#   'deaths': 2,
#   'recovered': 7,
#   'active': 23,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('828'),
#   'total_deaths_per_million': Decimal('52')},
#  {'country': 'Eritrea',
#   'confirmed': 29,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 29,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Bahamas',
#   'confirmed': 28,
#   'new_cases': 0,
#   'deaths': 4,
#   'recovered': 0,
#   'active': 24,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('71'),
#   'total_deaths_per_million': Decimal('10')},
#  {'country': 'Sint Maarten',
#   'confirmed': 25,
#   'new_cases': 2,
#   'deaths': 4,
#   'recovered': 1,
#   'active': 20,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 82,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('583'),
#   'total_deaths_per_million': Decimal('93')},
#  {'country': 'Guyana',
#   'confirmed': 24,
#   'new_cases': 1,
#   'deaths': 4,
#   'recovered': 0,
#   'active': 20,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 93,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('31'),
#   'total_deaths_per_million': Decimal('5')},
#  {'country': 'Tanzania',
#   'confirmed': 22,
#   'new_cases': 2,
#   'deaths': 1,
#   'recovered': 3,
#   'active': 18,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.4'),
#   'total_deaths_per_million': Decimal('0.02')},
#  {'country': 'Benin',
#   'confirmed': 22,
#   'new_cases': 6,
#   'deaths': 0,
#   'recovered': 5,
#   'active': 17,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Gabon',
#   'confirmed': 21,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 1,
#   'active': 19,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9'),
#   'total_deaths_per_million': Decimal('0.4')},
#  {'country': 'Haiti',
#   'confirmed': 21,
#   'new_cases': 1,
#   'deaths': 1,
#   'recovered': 1,
#   'active': 19,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 247,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0.09')},
#  {'country': 'Myanmar',
# ...
#  {'country': 'Libya',
#   'confirmed': 18,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 17,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 294,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0.1')},
#  {'country': 'Guinea-Bissau',
#   'confirmed': 18,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 18,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'New Caledonia',
#   'confirmed': 18,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 17,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1983,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('63'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Equatorial Guinea',
#   'confirmed': 16,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 15,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Namibia',
#   'confirmed': 16,
#   'new_cases': 2,
#   'deaths': 0,
#   'recovered': 3,
#   'active': 13,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 301,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Antigua and Barbuda',
#   'confirmed': 15,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 15,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 40,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('153'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Dominica',
#   'confirmed': 14,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 14,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 255,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('194'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Mongolia',
#   'confirmed': 14,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 2,
#   'active': 12,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Saint Lucia',
#   'confirmed': 14,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 13,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('76'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Liberia',
#   'confirmed': 13,
#   'new_cases': 3,
#   'deaths': 3,
#   'recovered': 3,
#   'active': 7,
#   'critical': 0,
#   'new_deaths': 2,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0.6')},
#  {'country': 'Sudan',
#   'confirmed': 12,
#   'new_cases': 2,
#   'deaths': 2,
#   'recovered': 2,
#   'active': 8,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.3'),
#   'total_deaths_per_million': Decimal('0.05')},
#  {'country': 'Fiji',
#   'confirmed': 12,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 12,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Grenada',
#   'confirmed': 12,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 12,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 45,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('107'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Curaçao',
#   'confirmed': 11,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 5,
#   'active': 5,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('67'),
#   'total_deaths_per_million': Decimal('6')},
#  {'country': 'Greenland',
#   'confirmed': 11,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 3,
#   'active': 8,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 542,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('194'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Laos',
#   'confirmed': 11,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 11,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 604,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Angola',
#   'confirmed': 10,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 2,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.3'),
#   'total_deaths_per_million': Decimal('0.06')},
#  {'country': 'Suriname',
#   'confirmed': 10,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 9,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Mozambique',
#   'confirmed': 10,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 9,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 338,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.3'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Saint Kitts and Nevis',
#   'confirmed': 10,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 10,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 149,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('188'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Seychelles',
#   'confirmed': 10,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 10,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('102'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'MS Zaandam',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 0,
#   'active': 7,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Zimbabwe',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 8,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 316,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.6'),
#   'total_deaths_per_million': Decimal('0.07')},
#  {'country': 'Nepal',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 8,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1521,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.3'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Chad',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 9,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.5'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Eswatini',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 9,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'CAR',
#   'confirmed': 8,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 8,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Cabo Verde',
#   'confirmed': 7,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13'),
#   'total_deaths_per_million': Decimal('2')},
#  {'country': 'Vatican City',
#   'confirmed': 7,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 7,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8739'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'St. Vincent Grenadines',
#   'confirmed': 7,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('63'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Somalia',
#   'confirmed': 7,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.4'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Botswana',
#   'confirmed': 6,
#   'new_cases': 2,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 5,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 966,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0.4')},
#  {'country': 'Mauritania',
#   'confirmed': 6,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 2,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 67,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Nicaragua',
#   'confirmed': 6,
#   'new_cases': 1,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 5,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.9'),
#   'total_deaths_per_million': Decimal('0.2')},
#  {'country': 'Montserrat',
#   'confirmed': 6,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1202'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'St. Barth',
#   'confirmed': 6,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 5,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('607'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Sierra Leone',
#   'confirmed': 6,
#   'new_cases': 2,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.8'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Turks and Caicos',
#   'confirmed': 5,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 0,
#   'active': 4,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('129'),
#   'total_deaths_per_million': Decimal('26')},
#  {'country': 'Belize',
#   'confirmed': 5,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 5,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 102,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Bhutan',
#   'confirmed': 5,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 2,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Gambia',
#   'confirmed': 4,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 2,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0.4')},
#  {'country': 'Malawi',
#   'confirmed': 4,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 4,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.2'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Western Sahara',
#   'confirmed': 4,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 4,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Anguilla',
#   'confirmed': 3,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('200'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'British Virgin Islands',
#   'confirmed': 3,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('99'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Burundi',
#   'confirmed': 3,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.3'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Caribbean Netherlands',
#   'confirmed': 2,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 10,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('76'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Falkland Islands',
#   'confirmed': 2,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('575'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Papua New Guinea',
#   'confirmed': 1,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 72,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.1'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Saint Pierre Miquelon',
#   'confirmed': 1,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('173'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'South Sudan',
#   'confirmed': 1,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.09'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'Timor-Leste',
#   'confirmed': 1,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 0,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.8'),
#   'total_deaths_per_million': Decimal('0')},
#  {'country': 'China',
#   'confirmed': 81669,
#   'new_cases': 30,
#   'deaths': 3329,
#   'recovered': 76964,
#   'active': 1376,
#   'critical': 295,
#   'new_deaths': 3,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('57'),
#   'total_deaths_per_million': Decimal('2')}]

# %%
covid.get_status_by_country_name('italy')
# Out:
# {'country': 'Italy',
#  'confirmed': 128948,
#  'new_cases': 4316,
#  'deaths': 15887,
#  'recovered': 21815,
#  'active': 91246,
#  'critical': 3977,
#  'new_deaths': 525,
#  'total_tests': 691461,
#  'total_tests_per_million': Decimal('0'),
#  'total_cases_per_million': Decimal('2133'),
#  'total_deaths_per_million': Decimal('263')}

# %%
covid.list_countries()
# Out:
# ['world',
#  'usa',
#  'spain',
#  'italy',
#  'germany',
#  'france',
#  'iran',
#  'uk',
#  'turkey',
#  'switzerland',
#  'belgium',
#  'netherlands',
#  'canada',
#  'austria',
#  'portugal',
#  'brazil',
#  's. korea',
#  'israel',
#  'sweden',
#  'norway',
#  'australia',
#  'russia',
#  'ireland',
#  'czechia',
#  'chile',
#  'denmark',
#  'poland',
#  'romania',
#  'malaysia',
#  'ecuador',
#  'india',
#  'philippines',
#  'pakistan',
#  'japan',
#  'luxembourg',
#  'saudi arabia',
#  'peru',
#  'indonesia',
#  'thailand',
#  'finland',
#  'serbia',
#  'mexico',
#  'panama',
#  'uae',
#  'dominican republic',
#  'greece',
#  'south africa',
#  'qatar',
#  'iceland',
#  'colombia',
#  'argentina',
#  'algeria',
#  'singapore',
#  'ukraine',
#  'croatia',
#  'egypt',
#  'estonia',
#  'new zealand',
#  'morocco',
#  'slovenia',
#  'iraq',
#  'hong kong',
#  'moldova',
#  'armenia',
#  'lithuania',
#  'hungary',
#  'diamond princess',
#  'bahrain',
#  'bosnia and herzegovina',
#  'cameroon',
#  'azerbaijan',
#  'kazakhstan',
#  'tunisia',
#  'belarus',
#  'kuwait',
#  'north macedonia',
#  'latvia',
#  'bulgaria',
#  'lebanon',
#  'andorra',
#  'slovakia',
#  'costa rica',
#  'cyprus',
#  'uruguay',
#  'taiwan',
#  'albania',
#  'afghanistan',
#  'burkina faso',
#  'jordan',
#  'réunion',
#  'uzbekistan',
#  'cuba',
#  'channel islands',
#  'oman',
#  'honduras',
#  'san marino',
#  'ivory coast',
#  'vietnam',
#  'palestine',
#  'nigeria',
#  'mauritius',
#  'malta',
#  'senegal',
#  'ghana',
#  'montenegro',
#  'niger',
#  'faeroe islands',
#  'sri lanka',
#  'georgia',
#  'venezuela',
#  'bolivia',
#  'drc',
#  'martinique',
#  'kyrgyzstan',
#  'kenya',
#  'brunei',
#  'guadeloupe',
#  'mayotte',
#  'isle of man',
#  'guinea',
#  'cambodia',
#  'trinidad and tobago',
#  'paraguay',
#  'rwanda',
#  'gibraltar',
#  'bangladesh',
#  'liechtenstein',
#  'monaco',
#  'madagascar',
#  'aruba',
#  'el salvador',
#  'guatemala',
#  'french guiana',
#  'djibouti',
#  'barbados',
#  'jamaica',
#  'uganda',
#  'congo',
#  'mali',
#  'togo',
#  'macao',
#  'ethiopia',
#  'french polynesia',
#  'zambia',
#  'bermuda',
#  'cayman islands',
#  'saint martin',
#  'eritrea',
#  'bahamas',
#  'sint maarten',
#  'guyana',
#  'tanzania',
#  'benin',
#  'gabon',
#  'haiti',
#  'myanmar',
#  'syria',
#  'maldives',
#  'libya',
#  'guinea-bissau',
#  'new caledonia',
#  'equatorial guinea',
#  'namibia',
#  'antigua and barbuda',
#  'dominica',
#  'mongolia',
#  'saint lucia',
#  'liberia',
#  'sudan',
#  'fiji',
#  'grenada',
#  'curaçao',
#  'greenland',
#  'laos',
#  'angola',
#  'suriname',
#  'mozambique',
#  'saint kitts and nevis',
#  'seychelles',
#  'ms zaandam',
#  'zimbabwe',
#  'nepal',
#  'chad',
#  'eswatini',
#  'car',
#  'cabo verde',
#  'vatican city',
#  'st. vincent grenadines',
#  'somalia',
#  'botswana',
#  'mauritania',
#  'nicaragua',
#  'montserrat',
#  'st. barth',
#  'sierra leone',
#  'turks and caicos',
#  'belize',
#  'bhutan',
#  'gambia',
#  'malawi',
#  'western sahara',
#  'anguilla',
#  'british virgin islands',
#  'burundi',
#  'caribbean netherlands',
#  'falkland islands',
#  'papua new guinea',
#  'saint pierre miquelon',
#  'south sudan',
#  'timor-leste',
#  'china']

# %%
covid.get_total_active_cases()
# Out:
# 936473

# %%
covid.get_total_confirmed_cases()
# Out:
# 1266782

# %%
covid.get_total_recovered()
# Out:
# 261132

# %%
covid.get_total_deaths()
# Out:
# 69177
